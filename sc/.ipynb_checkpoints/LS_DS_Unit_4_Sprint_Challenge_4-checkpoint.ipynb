# %% [markdown]
# # Lambda School Data Science Unit 4 Sprint Challenge 4
#
# ## RNNs, CNNs, AutoML, and more...
#
# In this sprint challenge, you'll explore some of the cutting edge of Data Science.
#
# *Caution* - these approaches can be pretty heavy computationally. All problems were designed so that you should be able to achieve results within at most 5-10 minutes of runtime on Colab or a comparable environment. If something is running longer, doublecheck your approach!

# %% [markdown]
# ## Part 1 - RNNs
#
# Use an RNN to fit a simple classification model on tweets to distinguish from tweets from Austen Allred and tweets from Weird Al Yankovic.
#
# Following is code to scrape the needed data (no API auth needed, uses [twitterscraper](https://github.com/taspinar/twitterscraper)):

# %%
# !pip install twitterscraper
# Out:
# Requirement already satisfied: twitterscraper in /home/rick1270/anaconda3/lib/python3.6/site-packages (0.9.3)
# Requirement already satisfied: bs4 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from twitterscraper) (0.0.1)
# Requirement already satisfied: coala-utils~=0.5.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from twitterscraper) (0.5.1)
# Requirement already satisfied: lxml in /home/rick1270/anaconda3/lib/python3.6/site-packages (from twitterscraper) (4.2.1)
# Requirement already satisfied: requests in /home/rick1270/anaconda3/lib/python3.6/site-packages (from twitterscraper) (2.18.4)
# Requirement already satisfied: beautifulsoup4 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from bs4->twitterscraper) (4.6.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests->twitterscraper) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests->twitterscraper) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests->twitterscraper) (2018.4.16)

# %%
from twitterscraper import query_tweets

austen_tweets = query_tweets('from:austen', 1000)
len(austen_tweets)
# Out:
# INFO: queries: ['from:austen since:2006-03-21 until:2006-11-14', 'from:austen since:2006-11-14 until:2007-07-11', 'from:austen since:2007-07-11 until:2008-03-05', 'from:austen since:2008-03-05 until:2008-10-30', 'from:austen since:2008-10-30 until:2009-06-25', 'from:austen since:2009-06-25 until:2010-02-19', 'from:austen since:2010-02-19 until:2010-10-15', 'from:austen since:2010-10-15 until:2011-06-11', 'from:austen since:2011-06-11 until:2012-02-04', 'from:austen since:2012-02-04 until:2012-09-30', 'from:austen since:2012-09-30 until:2013-05-26', 'from:austen since:2013-05-26 until:2014-01-20', 'from:austen since:2014-01-20 until:2014-09-15', 'from:austen since:2014-09-15 until:2015-05-12', 'from:austen since:2015-05-12 until:2016-01-05', 'from:austen since:2016-01-05 until:2016-08-31', 'from:austen since:2016-08-31 until:2017-04-26', 'from:austen since:2017-04-26 until:2017-12-21', 'from:austen since:2017-12-21 until:2018-08-16', 'from:austen since:2018-08-16 until:2019-04-12']
# INFO: Querying from:austen since:2007-07-11 until:2008-03-05
# INFO: Querying from:austen since:2010-02-19 until:2010-10-15
# INFO: Querying from:austen since:2009-06-25 until:2010-02-19
# INFO: Querying from:austen since:2008-03-05 until:2008-10-30
# INFO: Querying from:austen since:2006-11-14 until:2007-07-11
# INFO: Querying from:austen since:2006-03-21 until:2006-11-14
# INFO: Querying from:austen since:2008-10-30 until:2009-06-25
# INFO: Querying from:austen since:2011-06-11 until:2012-02-04
# INFO: Querying from:austen since:2014-09-15 until:2015-05-12
# INFO: Querying from:austen since:2010-10-15 until:2011-06-11
# INFO: Querying from:austen since:2015-05-12 until:2016-01-05
# INFO: Querying from:austen since:2017-12-21 until:2018-08-16
# INFO: Querying from:austen since:2018-08-16 until:2019-04-12
# INFO: Querying from:austen since:2017-04-26 until:2017-12-21
# INFO: Querying from:austen since:2016-08-31 until:2017-04-26
# INFO: Querying from:austen since:2012-09-30 until:2013-05-26
# INFO: Querying from:austen since:2016-01-05 until:2016-08-31
# INFO: Querying from:austen since:2012-02-04 until:2012-09-30
# INFO: Querying from:austen since:2014-01-20 until:2014-09-15
# INFO: Querying from:austen since:2013-05-26 until:2014-01-20
# INFO: Got 0 tweets for from%3Aausten%20since%3A2007-07-11%20until%3A2008-03-05.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2011-06-11%20until%3A2012-02-04.
# INFO: Got 0 tweets for from%3Aausten%20since%3A2006-03-21%20until%3A2006-11-14.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2016-08-31%20until%3A2017-04-26.
# INFO: Got 0 tweets for from%3Aausten%20since%3A2006-11-14%20until%3A2007-07-11.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2015-05-12%20until%3A2016-01-05.
# INFO: Got 0 tweets for from%3Aausten%20since%3A2014-09-15%20until%3A2015-05-12.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2010-10-15%20until%3A2011-06-11.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2010-02-19%20until%3A2010-10-15.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2013-05-26%20until%3A2014-01-20.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2009-06-25%20until%3A2010-02-19.
# INFO: Got 0 tweets for from%3Aausten%20since%3A2008-03-05%20until%3A2008-10-30.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2012-09-30%20until%3A2013-05-26.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2016-01-05%20until%3A2016-08-31.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2014-01-20%20until%3A2014-09-15.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3Aausten%20since%3A2008-10-30%20until%3A2009-06-25.
# INFO: Got 0 tweets (0 new).
# INFO: Got 1 tweets for from%3Aausten%20since%3A2012-02-04%20until%3A2012-09-30.
# INFO: Got 1 tweets (1 new).
# INFO: Got 60 tweets for from%3Aausten%20since%3A2017-04-26%20until%3A2017-12-21.
# INFO: Got 61 tweets (60 new).
# INFO: Got 60 tweets for from%3Aausten%20since%3A2017-12-21%20until%3A2018-08-16.
# INFO: Got 60 tweets for from%3Aausten%20since%3A2018-08-16%20until%3A2019-04-12.
# INFO: Got 121 tweets (60 new).
# INFO: Got 181 tweets (60 new).
# 181

# %%
austen_tweets[0].text
# Out:
# 'I love love love working with great people.pic.twitter.com/fCKOm6Vl'

# %%
al_tweets = query_tweets('from:AlYankovic', 1000)
len(al_tweets)
# Out:
# INFO: queries: ['from:AlYankovic since:2006-03-21 until:2006-11-14', 'from:AlYankovic since:2006-11-14 until:2007-07-11', 'from:AlYankovic since:2007-07-11 until:2008-03-05', 'from:AlYankovic since:2008-03-05 until:2008-10-30', 'from:AlYankovic since:2008-10-30 until:2009-06-25', 'from:AlYankovic since:2009-06-25 until:2010-02-19', 'from:AlYankovic since:2010-02-19 until:2010-10-15', 'from:AlYankovic since:2010-10-15 until:2011-06-11', 'from:AlYankovic since:2011-06-11 until:2012-02-04', 'from:AlYankovic since:2012-02-04 until:2012-09-30', 'from:AlYankovic since:2012-09-30 until:2013-05-26', 'from:AlYankovic since:2013-05-26 until:2014-01-20', 'from:AlYankovic since:2014-01-20 until:2014-09-15', 'from:AlYankovic since:2014-09-15 until:2015-05-12', 'from:AlYankovic since:2015-05-12 until:2016-01-05', 'from:AlYankovic since:2016-01-05 until:2016-08-31', 'from:AlYankovic since:2016-08-31 until:2017-04-26', 'from:AlYankovic since:2017-04-26 until:2017-12-21', 'from:AlYankovic since:2017-12-21 until:2018-08-16', 'from:AlYankovic since:2018-08-16 until:2019-04-12']
# INFO: Querying from:AlYankovic since:2008-03-05 until:2008-10-30
# INFO: Querying from:AlYankovic since:2006-03-21 until:2006-11-14
# INFO: Querying from:AlYankovic since:2006-11-14 until:2007-07-11
# INFO: Querying from:AlYankovic since:2010-10-15 until:2011-06-11
# INFO: Querying from:AlYankovic since:2008-10-30 until:2009-06-25
# INFO: Querying from:AlYankovic since:2007-07-11 until:2008-03-05
# INFO: Querying from:AlYankovic since:2014-09-15 until:2015-05-12
# INFO: Querying from:AlYankovic since:2011-06-11 until:2012-02-04
# INFO: Querying from:AlYankovic since:2010-02-19 until:2010-10-15
# INFO: Querying from:AlYankovic since:2016-01-05 until:2016-08-31
# INFO: Querying from:AlYankovic since:2015-05-12 until:2016-01-05
# INFO: Querying from:AlYankovic since:2016-08-31 until:2017-04-26
# INFO: Querying from:AlYankovic since:2009-06-25 until:2010-02-19
# INFO: Querying from:AlYankovic since:2017-12-21 until:2018-08-16
# INFO: Querying from:AlYankovic since:2017-04-26 until:2017-12-21
# INFO: Querying from:AlYankovic since:2012-09-30 until:2013-05-26
# INFO: Querying from:AlYankovic since:2013-05-26 until:2014-01-20
# INFO: Querying from:AlYankovic since:2012-02-04 until:2012-09-30
# INFO: Querying from:AlYankovic since:2018-08-16 until:2019-04-12
# INFO: Querying from:AlYankovic since:2014-01-20 until:2014-09-15
# INFO: Got 0 tweets for from%3AAlYankovic%20since%3A2006-03-21%20until%3A2006-11-14.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3AAlYankovic%20since%3A2007-07-11%20until%3A2008-03-05.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3AAlYankovic%20since%3A2006-11-14%20until%3A2007-07-11.
# INFO: Got 0 tweets (0 new).
# INFO: Got 0 tweets for from%3AAlYankovic%20since%3A2008-03-05%20until%3A2008-10-30.
# INFO: Got 0 tweets (0 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2014-09-15%20until%3A2015-05-12.
# INFO: Got 60 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2010-10-15%20until%3A2011-06-11.
# INFO: Got 120 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2012-02-04%20until%3A2012-09-30.
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2015-05-12%20until%3A2016-01-05.
# INFO: Got 180 tweets (60 new).
# INFO: Got 240 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2010-02-19%20until%3A2010-10-15.
# INFO: Got 300 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2013-05-26%20until%3A2014-01-20.
# INFO: Got 360 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2008-10-30%20until%3A2009-06-25.
# INFO: Got 420 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2016-01-05%20until%3A2016-08-31.
# INFO: Got 480 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2017-04-26%20until%3A2017-12-21.
# INFO: Got 540 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2011-06-11%20until%3A2012-02-04.
# INFO: Got 600 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2009-06-25%20until%3A2010-02-19.
# INFO: Got 660 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2017-12-21%20until%3A2018-08-16.
# INFO: Got 720 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2014-01-20%20until%3A2014-09-15.
# INFO: Got 780 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2018-08-16%20until%3A2019-04-12.
# INFO: Got 840 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2012-09-30%20until%3A2013-05-26.
# INFO: Got 900 tweets (60 new).
# INFO: Got 60 tweets for from%3AAlYankovic%20since%3A2016-08-31%20until%3A2017-04-26.
# INFO: Got 960 tweets (60 new).
# 960

# %%
al_tweets[0].text
# Out:
# "See?  I wasn't kidding!pic.twitter.com/acLDlNamPF"

# %%
len(austen_tweets + al_tweets)
# Out:
# 1141

# %% [markdown]
# Your tasks:
#
# - Encode the characters to a sequence of integers for the model
# - Get the data into the appropriate shape/format, including labels and a train/test split
# - Use Keras to fit a predictive model, classifying tweets as being from Austen versus Weird Al
# - Report your overall score and accuracy
#
# For reference, the [Keras IMDB sentiment classification example](https://github.com/keras-team/keras/blob/master/examples/imdb_lstm.py) will be useful, as well the RNN code we used in class.
#
# *Note* - focus on getting a running model, not on maxing accuracy with extreme data size or epoch numbers. Only revisit and push accuracy if you get everything else done!

# %%
#Convert tweets to CSV ... and add binary author to view
import pandas as pd
import numpy as np

def con_tweet(tweet_file, binary):
    tweets = []
    for i in range(0, len(tweet_file)):
        tweets.append(tweet_file[i].text)
    by = []
    for j in range(0, len(tweet_file)):
        by.append(binary)
    df= pd.DataFrame()
    df['Tweets'] = tweets
    df['By'] = by
    return df
        

df_al = con_tweet(al_tweets, 0)
df_austen = con_tweet(austen_tweets, 1)

print(df_al.head())
print(df_austen.head())
# Out:
#                                               Tweets  By
# 0  See?  I wasn't kidding!pic.twitter.com/acLDlNamPF   0
# 1  Thank you, I’ll be here all week!pic.twitter.c...   0
# 2  Just about to jump on a plane… guess this is r...   0
# 3         #HappyMothersDaypic.twitter.com/HzkO7sxUpi   0
# 4                Elephant Ridehttp://bit.ly/1bH1Q2n    0
#                                               Tweets  By
# 0  I love love love working with great people.pic...   1
# 1                   Elon Musk is severely underrated   1
# 2      SpaceX 2002 vs 2017pic.twitter.com/dtzBID2Q3v   1
# 3                            Yes. On the blockchain.   1
# 4  This is a publicly traded company with no reve...   1

# %%
tweets_len = []

for i in range(len(austen_tweets)):
  tweet_len = len(austen_tweets[i].text)
  tweets_len.append(tweet_len)

print('Austen tweet lengths:')
print(f'max: {max(tweets_len)}, min: {min(tweets_len)}')

tweets_len = []

for i in range(len(al_tweets)):
  tweet_len = len(al_tweets[i].text)    
  tweets_len.append(tweet_len)
  
print('AlYankovic tweet lengths:')
print(f'max: {max(tweets_len)}, min: {min(tweets_len)}')
# Out:
# Austen tweet lengths:
# max: 297, min: 2
# AlYankovic tweet lengths:
# max: 305, min: 5

# %%
# Encode the characters to a sequence of integers for the model

def convert_to_ascii(text):
  ascii_list = [ord(char) for char in text]

  #return ",".join(str(ord(char)) for char in text)
  return ascii_list
  
# output = convert_to_ascii('hello')
# print(output)

austen_tweets_updated = []

for i in range(len(austen_tweets)):
  updated_text = convert_to_ascii(austen_tweets[i].text)
  austen_tweets_updated.append(updated_text)
  
al_tweets_updated = []

for i in range(len(al_tweets)):
  updated_text = convert_to_ascii(al_tweets[i].text)
  al_tweets_updated.append(updated_text)
  

print('Initial tweet counts')
print(len(austen_tweets))
print(len(al_tweets))

print('Updated tweet counts')
print(len(austen_tweets_updated))
print(len(al_tweets_updated))
# Out:
# Initial tweet counts
# 181
# 960
# Updated tweet counts
# 181
# 960

# %%
# Get the data into the appropriate shape/format, including labels 
# and a train/test split

combined_updated_tweets = austen_tweets_updated + al_tweets_updated
print('Combined tweet counts')
print(len(combined_updated_tweets))
print(combined_updated_tweets)

X = np.array(combined_updated_tweets)
# print(X)

austen_tweets_label = np.ones((len(austen_tweets_updated),), dtype=np.int)
al_tweets_lable = np.zeros((len(al_tweets_updated),), dtype=np.int)

y = np.concatenate((austen_tweets_label,al_tweets_lable), axis=0)
# Out:
# Combined tweet counts
# 1141
# [[73, 32, 108, 111, 118, 101, 32, 108, 111, 118, 101, 32, 108, 111, 118, 101, 32, 119, 111, 114, 107, 105, 110, 103, 32, 119, 105, 116, 104, 32, 103, 114, 101, 97, 116, 32, 112, 101, 111, 112, 108, 101, 46, 112, 105, 99, 46, 116, 119, 105, 116, 116, 101, 114, 46, 99, 111, 109, 47, 102, 67, 75, 79, 109, 54, 86, 108], [69, 108, 111, 110, 32, 77, 117, 115, 107, 32, 105, 115, 32, 115, 101, 118, 101, 114, 101, 108, 121, 32, 117, 110, 100, 101, 114, 114, 97, 116, 101, 100], [83, 112, 97, 99, 101, 88, 32, 50, 48, 48, 50, 32, 118, 115, 32, 50, 48, 49, 55, 112, 105, 99, 46, 116, 119, 105, 116, 116, 101, 114, 46, 99, 111, 109, 47, 100, 116, 122, 66, 73, 68, 50, 81, 51, 118], [89, 101, 115, 46, 32, 79, 110, 32, 116, 104, 101, 32, 98, 108, 111, 99, 107, 99, 104, 97, 105, 110, 46], [84, 104, 105, 115, 32, 105, 115, 32, 97, 32, 112, 117, 98, 108, 105, 99, 108, 121, 32, 116, 114, 97, 100, 101, 100, 32, 99, 111, 109, 112, 97, 110, 121, 32, 119, 105, 116, 104, 32, 110, 111, 32, 114, 101, 118, 101, 110, 117, 101, 32, 97, 110, 100, 32, 97, 32, 36, 51, 32, 66, 105, 108, 108, 105, 111, 110, 43, 32, 109, 97, 114, 107, 101, 116, 32, 99, 97, 112, 58, 32, 104, 116, 116, 112, 58, 47, 47, 119, 119, 119, 46, 108, 111, 110, 103, 102, 105, 110, 99, 111, 114, 112, 46, 99, 111, 109, 47, 98, 117, 115, 105, 110, 101, 115, 115, 46, 104, 116, 109, 108, 160, 46, 32, 83, 116, 97, 114, 116, 105, 110, 103, 32, 116, 111, 32, 103, 101, 116, 32, 97, 32, 115, 101, 110, 115, 101, 32, 102, 111, 114, 32, 119, 104, 97, 116, 32, 49, 57, 57, 57, 32, 119, 97, 115, 32, 108, 105, 107, 101, 46, 32, 36, 76, 70, 73, 78], [112, 105, 99, 46, 116, 119, 105, 116, 116, 101, 114, 46, 99, 111, 109, 47, 116, 53, 75, 48, 84, 71, 56, 54, 103, 115], [67, 111, 110, 118, 111, 32, 105, 110, 32, 116, 104, 101, 32, 64, 76, 97, 109, 98, 100, 97, 83, 99, 104, 111, 111, 108, 32, 83, 108, 97, 99, 107, 32, 114, 105, 103, 104, 116, 32, 110, 111, 119, 58, 10, 10, 34, 73, 32, 115, 116, 97, 114, 116, 101, 100, 32, 116, 119, 111, 32, 111, 116, 104, 101, 114, 32, 98, 111, 111, 116, 99, 97, 109, 112, 115, 32, 98, 101, 102, 111, 114, 101, 32, 76, 97, 109, 98, 100, 97, 32, 83, 99, 104, 111, 111, 108, 44, 32, 116, 104, 101, 110, 32, 113, 117, 105, 116, 32, 98, 101, 99, 97, 117, 115, 101, 32, 73, 32, 108, 101, 97, 114, 110, 101, 100, 32, 109, 111, 114, 101, 32, 105, 110, 32, 116, 104, 101, 32, 112, 114, 101, 99, 111, 117, 114, 115, 101, 32, 119, 111, 114, 107, 32, 97, 116, 32, 76, 97, 109, 98, 100, 97, 32, 116, 104, 97, 110, 32, 54, 32, 97, 110, 100, 32, 56, 32, 119, 101, 101, 107, 115, 32, 116, 104, 101, 114, 101, 46, 34, 10, 10, 34, 73, 32, 104, 97, 118, 101, 32, 97, 32, 67, 83, 32, 100, 101, 103, 114, 101, 101, 32, 97, 110, 100, 32, 73, 32, 108, 101, 97, 114, 110, 32, 109, 111, 114, 101, 32, 119, 105, 116, 104, 32, 76, 97, 109, 98, 100, 97, 32, 116, 104, 97, 110, 32, 73, 32, 100, 105, 100, 32, 119, 105, 116, 104, 32, 116, 104, 97, 116, 46, 34], [83, 116, 97, 114, 116, 117, 112, 32, 114, 111, 97, 100, 109, 97, 112, 32, 50, 48, 49, 55, 58, 10, 10, 70, 105, 110, 100, 32, 97, 110, 32, 105, 110, 100, 117, 115, 116, 114, 121, 32, 105, 110, 115, 117, 108, 97, 116, 101, 100, 32, 98, 121, 32, 114, 101, 103, 117, 108, 97, 116, 105, 111, 110, 32, 97, 110, 100, 47, 111, 114, 32, 98, 101, 105, 110, 103, 32, 98, 111, 114, 105, 110, 103, 46, 10, 10, 69, 110, 116, 101, 114, 32, 105, 110, 100, 117, 115, 116, 114, 121, 32, 119, 105, 116, 104, 32, 115, 111, 102, 116, 119, 97, 114, 101, 46, 10, 10, 73, 110, 100, 117, 115, 116, 114, 121, 32, 116, 104, 105, 110, 107, 115, 32, 121, 111, 117, 8217, 114, 101, 32, 97, 32, 112, 117, 110, 107, 32, 107, 105, 100, 32, 116, 104, 97, 116, 32, 99, 97, 110, 8217, 116, 32, 112, 111, 115, 115, 105, 98, 108, 121, 32, 117, 110, 100, 101, 114, 115, 116, 97, 110, 100, 32, 105, 110, 116, 114, 105, 99, 97, 99, 105, 101, 115, 32, 111, 102, 32, 120, 46, 32, 84, 104, 101, 121, 8217, 114, 101, 32, 114, 105, 103, 104, 116, 32, 97, 116, 32, 102, 105, 114, 115, 116, 44, 32, 98, 117, 116, 32, 121, 111, 117, 3 ...

# %%
# Use Keras to fit a predictive model, classifying tweets as being 
# from Austen versus Weird Al

from sklearn.model_selection import train_test_split
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.datasets import imdb

max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 290
batch_size = 32

print('Loading data...')
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# print(x_train)
# print(y_train)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# /home/rick1270/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Loading data...
# 798 train sequences
# 343 test sequences
# Pad sequences (samples x time)
# x_train shape: (798, 290)
# x_test shape: (343, 290)
# Build model...
# WARNING:tensorflow:From /home/rick1270/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/rick1270/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train...
# WARNING:tensorflow:From /home/rick1270/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 798 samples, validate on 343 samples
# Epoch 1/15
# 798/798 [==============================] - 10s 12ms/step - loss: 0.4862 - acc: 0.8383 - val_loss: 0.3659 - val_acc: 0.8542
# Epoch 2/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.3448 - acc: 0.8684 - val_loss: 0.2994 - val_acc: 0.8863
# Epoch 3/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.3009 - acc: 0.8734 - val_loss: 0.3218 - val_acc: 0.8601
# Epoch 4/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2849 - acc: 0.8897 - val_loss: 0.2905 - val_acc: 0.8834
# Epoch 5/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2545 - acc: 0.9060 - val_loss: 0.2594 - val_acc: 0.9096
# Epoch 6/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2482 - acc: 0.9110 - val_loss: 0.2532 - val_acc: 0.9155
# Epoch 7/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2769 - acc: 0.8784 - val_loss: 0.2933 - val_acc: 0.8921
# Epoch 8/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2462 - acc: 0.9123 - val_loss: 0.2628 - val_acc: 0.8980
# Epoch 9/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2164 - acc: 0.9148 - val_loss: 0.2467 - val_acc: 0.9125
# Epoch 10/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2136 - acc: 0.9198 - val_loss: 0.2504 - val_acc: 0.9155
# Epoch 11/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2277 - acc: 0.9110 - val_loss: 0.2783 - val_acc: 0.9067
# Epoch 12/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.2233 - acc: 0.9123 - val_loss: 0.2610 - val_acc: 0.8980
# Epoch 13/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.1907 - acc: 0.9323 - val_loss: 0.2266 - val_acc: 0.9155
# Epoch 14/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.1790 - acc: 0.9198 - val_loss: 0.2558 - val_acc: 0.8950
# Epoch 15/15
# 798/798 [==============================] - 8s 10ms/step - loss: 0.1648 - acc: 0.9398 - val_loss: 0.2439 - val_acc: 0.9213
# 343/343 [==============================] - 1s 2ms/step
# Test score: 0.24393361415876938
# Test accuracy: 0.921282800224015

# %% [markdown]
# Conclusion - RNN runs, and gives pretty decent improvement over a naive "It's Al!" model. To *really* improve the model, more playing with parameters, and just getting more data (particularly Austen tweets), would help. Also - RNN may well not be the best approach here, but it is at least a valid one.

# %% [markdown]
# ## Part 2- CNNs
#
# Time to play "find the frog!" Use Keras and ResNet50 to detect which of the following images contain frogs:

# %%
# !pip install google_images_download
# Out:
# Requirement already satisfied: google_images_download in /home/rick1270/anaconda3/lib/python3.6/site-packages (2.5.0)
# Requirement already satisfied: selenium in /home/rick1270/anaconda3/lib/python3.6/site-packages (from google_images_download) (3.141.0)
# Requirement already satisfied: urllib3 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from selenium->google_images_download) (1.22)

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()
arguments = {"keywords": "animal pond", "limit": 5, "print_urls": True}
absolute_image_paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = animal pond
# Evaluating...
# Starting Download...
# Image URL: https://www.enchantedlearning.com/pgifs/Pondanimals.GIF
# Completed Image ====> 1. pondanimals.gif
# Image URL: https://i.ytimg.com/vi/NCbu0TND9vE/hqdefault.jpg
# Completed Image ====> 2. hqdefault.jpg
# Image URL: https://pklifescience.com/staticfiles/articles/images/PKLS4116_inline.png
# Completed Image ====> 3. pkls4116_inline.png
# Image URL: https://pixnio.com/free-images/fauna-animals/reptiles-and-amphibians/alligators-and-crocodiles-pictures/alligator-animal-on-pond.jpg
# Completed Image ====> 4. alligator-animal-on-pond.jpg
# Image URL: https://www.nwf.org/-/media/NEW-WEBSITE/Programs/Garden-for-Wildlife/amphibian_bronze-frog_Julia-Bartosh_400x267.ashx
# Completed Image ====> 5. amphibian_bronze-frog_julia-bartosh_400x267.ash
#
# Errors: 0

# %% [markdown]
# At time of writing at least a few do, but since the Internet changes - it is possible your 5 won't. You can easily verify yourself, and (once you have working code) increase the number of images you pull to be more sure of getting a frog. Your goal is to validly run ResNet50 on the input images - don't worry about tuning or improving the model.
#
# *Hint* - ResNet 50 doesn't just return "frog". The three labels it has for frogs are: `bullfrog, tree frog, tailed frog`
#
# *Stretch goal* - also check for fish.

# %%
# Imports
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageOps  # https://pillow.readthedocs.io/en/stable/
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
absolute_image_paths
# Out:
# {'animal pond': ['/home/rick1270/repos/rclayton/DS-Unit-4-Spring-4-Deep-Learning/sc/downloads/animal pond/1. pondanimals.gif',
#   '/home/rick1270/repos/rclayton/DS-Unit-4-Spring-4-Deep-Learning/sc/downloads/animal pond/2. hqdefault.jpg',
#   '/home/rick1270/repos/rclayton/DS-Unit-4-Spring-4-Deep-Learning/sc/downloads/animal pond/3. pkls4116_inline.png',
#   '/home/rick1270/repos/rclayton/DS-Unit-4-Spring-4-Deep-Learning/sc/downloads/animal pond/4. alligator-animal-on-pond.jpg',
#   '/home/rick1270/repos/rclayton/DS-Unit-4-Spring-4-Deep-Learning/sc/downloads/animal pond/5. amphibian_bronze-frog_julia-bartosh_400x267.ash']}

# %%
# Resize all images to 224x224 pixels
image_path_list = absolute_image_paths['animal pond']

def resize_image(filename, new_width=256, new_height=256):
  pil_image = Image.open(filename)
  pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
  pil_image_rgb = pil_image.convert('RGB')
  pil_image_rgb.save(filename, format='JPEG', quality=90)

for path in image_path_list:
  resize_image(path, 224, 224)

# %%
# Show images
def show_images(image_path_list):
  plt.figure(figsize=(10,10));
  for i, image_path in enumerate(image_path_list):
    plt.subplot(3,2, i+1)
    plt.imshow(np.asarray(Image.open(image_path)))
#     plt.title(image_path)
    plt.grid(False)
    plt.yticks([])
    plt.xticks([])
  plt.show()

show_images(image_path_list)

# %%
def process_img_path(img_path):
  return image.load_img(img_path, target_size=(224, 224))

def interpret(img):
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  model = ResNet50(weights='imagenet')
  features = model.predict(x)
  results = decode_predictions(features, top=3)[0]
  return results

# %%
all_predictions = []
for i, image_path in enumerate(image_path_list):
  results = interpret(process_img_path(image_path))
  all_predictions.append(results)
  print(results)
# Out:
# [('n06359193', 'web_site', 0.89183867), ('n04404412', 'television', 0.0854772), ('n04152593', 'screen', 0.006043829)]
# [('n01443537', 'goldfish', 0.577143), ('n02536864', 'coho', 0.31938618), ('n01630670', 'common_newt', 0.020655122)]
# [('n04243546', 'slot', 0.957449), ('n04476259', 'tray', 0.014238194), ('n03908618', 'pencil_box', 0.007384071)]
# [('n01698640', 'American_alligator', 0.5908738), ('n01737021', 'water_snake', 0.13598225), ('n01697457', 'African_crocodile', 0.07479113)]
# [('n01641577', 'bullfrog', 0.66036457), ('n01644900', 'tailed_frog', 0.31086266), ('n01630670', 'common_newt', 0.012726638)]

# %%
for path, prediction in zip(image_path_list, all_predictions):
  
  # If any of the predictions for an image include the word 'frog', 
  # print out all the predictions as well as the image.
  if any(['frog' in x[1] for x in prediction]):
    
    print("ResNet50 thinks there's a frog in here!")
    print()
    for _, animal, prob in prediction:
      print(f'{prob*100:6.2f}% chance of {animal} ')

    plt.subplot()
    plt.imshow(np.asarray(Image.open(path)))
    plt.grid(False)
    plt.yticks([])
    plt.xticks([])
    plt.show()
    print()
# Out:
# ResNet50 thinks there's a frog in here!
#
#  66.04% chance of bullfrog
#  31.09% chance of tailed_frog
#   1.27% chance of common_newt

# %% [markdown]
# ## Part 3 - AutoML
#
# Use [TPOT](https://github.com/EpistasisLab/tpot) to fit a predictive model for the King County housing data, with `price` as the target output variable.

# %%
# !pip install tpot
# Out:
# Requirement already satisfied: tpot in /home/rick1270/anaconda3/lib/python3.6/site-packages (0.10.0)
# Requirement already satisfied: scikit-learn>=0.18.1 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (0.19.1)
# Requirement already satisfied: tqdm>=4.26.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (4.31.1)
# Requirement already satisfied: deap>=1.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (1.2.2)
# Requirement already satisfied: numpy>=1.12.1 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (1.14.3)
# Requirement already satisfied: pandas>=0.20.2 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (0.23.0)
# Requirement already satisfied: scipy>=0.19.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (1.1.0)
# Requirement already satisfied: update-checker>=0.16 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (0.16)
# Requirement already satisfied: stopit>=1.1.1 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from pandas>=0.20.2->tpot) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/rick1270/anaconda3/lib/python3.6/site-packages (from pandas>=0.20.2->tpot) (2018.4)
# Requirement already satisfied: requests>=2.3.0 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from update-checker>=0.16->tpot) (2.18.4)
# Requirement already satisfied: six>=1.5 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.20.2->tpot) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rick1270/anaconda3/lib/python3.6/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2018.4.16)

# %%
# !wget https://raw.githubusercontent.com/ryanleeallred/datasets/master/kc_house_data.csv
# Out:
# --2019-04-12 10:58:06--  https://raw.githubusercontent.com/ryanleeallred/datasets/master/kc_house_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.192.133, 151.101.64.133, 151.101.0.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.192.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [text/plain]
# Saving to: ‘kc_house_data.csv.1’
#
# kc_house_data.csv.1 100%[===================>]   2.40M  13.0MB/s    in 0.2s
#
# 2019-04-12 10:58:07 (13.0 MB/s) - ‘kc_house_data.csv.1’ saved [2515206/2515206]

# %%
# !head kc_house_data.csv
# Out:
# id,date,price,bedrooms,bathrooms,sqft_living,sqft_lot,floors,waterfront,view,condition,grade,sqft_above,sqft_basement,yr_built,yr_renovated,zipcode,lat,long,sqft_living15,sqft_lot15
# "7129300520","20141013T000000",221900,3,1,1180,5650,"1",0,0,3,7,1180,0,1955,0,"98178",47.5112,-122.257,1340,5650
# "6414100192","20141209T000000",538000,3,2.25,2570,7242,"2",0,0,3,7,2170,400,1951,1991,"98125",47.721,-122.319,1690,7639
# "5631500400","20150225T000000",180000,2,1,770,10000,"1",0,0,3,6,770,0,1933,0,"98028",47.7379,-122.233,2720,8062
# "2487200875","20141209T000000",604000,4,3,1960,5000,"1",0,0,5,7,1050,910,1965,0,"98136",47.5208,-122.393,1360,5000
# "1954400510","20150218T000000",510000,3,2,1680,8080,"1",0,0,3,8,1680,0,1987,0,"98074",47.6168,-122.045,1800,7503
# "7237550310","20140512T000000",1.225e+006,4,4.5,5420,101930,"1",0,0,3,11,3890,1530,2001,0,"98053",47.6561,-122.005,4760,101930
# "1321400060","20140627T000000",257500,3,2.25,1715,6819,"2",0,0,3,7,1715,0,1995,0,"98003",47.3097,-122.327,2238,6819
# "2008000270","20150115T000000",291850,3,1.5,1060,9711,"1",0,0,3,7,1060,0,1963,0,"98198",47.4095,-122.315,1650,9711
# "2414600126","20150415T000000",229500,3,1,1780,7470,"1",0,0,3,7,1050,730,1960,0,"98146",47.5123,-122.337,1780,8113

# %% [markdown]
# As with previous questions, your goal is to run TPOT and successfully run and report error at the end.  Also, in the interest of time, feel free to choose small `generation=1` and `population_size=10` parameters so your pipeline runs efficiently and you are able to iterate and test.
#
# *Hint* - you'll have to drop and/or type coerce at least a few variables to get things working. It's fine to err on the side of dropping to get things running, as long as you still get a valid model with reasonable predictive power.

# %%
from tpot import TPOTRegressor


df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
X = df.drop(columns=['price','date'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.75, test_size=0.25)

# %%
# %%time

tpot = TPOTRegressor(generations=1, population_size=10, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# Warning: xgboost.XGBRegressor is not available and will not be used by TPOT.
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=20, style=ProgressStyle(descripti…
# Generation 1 - Current best internal CV score: -25649605971.575645
#
# Best pipeline: ExtraTreesRegressor(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), bootstrap=True, max_features=0.8, min_samples_leaf=18, min_samples_split=11, n_estimators=100)
# -23806697291.047573
# CPU times: user 2min 49s, sys: 349 ms, total: 2min 49s
# Wall time: 2min 17s

# %%
y_test_predict = tpot.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

MSE = mean_squared_error(y_test, y_test_predict)
RMSE = (np.sqrt(MSE))

print('MSE is {}'.format(MSE))
print('RMSE is {}'.format(RMSE))

R2 = r2_score(y_test, y_test_predict)

print('R^2 is {}'.format(R2))
# Out:
# MSE is 23806697291.047573
# RMSE is 154294.19072359003
# R^2 is 0.8180057803755401

# %% [markdown]
# ## Part 4 - More...

# %% [markdown]
# Answer the following questions, with a target audience of a fellow Data Scientist:
#
# - What do you consider your strongest area, as a Data Scientist?
# I consider my stringest area of data science to be data wrangling/ clean up.  Additionally, I am strong at presenting and explaining output in a manner that is understandable to all while also being informative to more advanced audiences.
#
# - What area of Data Science would you most like to learn more about, and why?
# Predictive modeling interest me the most.  I can quickly see real world applications and ejoy the tangability (if that is a word) or measurements such as "accuracy score"
#
# - Where do you think Data Science will be in 5 years?
# I see data science as growing and becoming more sought after.  I think people will come to expect accurate predictions coming from models.  Additionally, I see the bar being set ever higher as applications become more complex.  DS has and will catapult many areas of science to the next level.
#
# A few sentences per answer is fine - only elaborate if time allows.

# %% [markdown]
# Thank you for your hard work, and congratulations! You've learned a lot, and should proudly call yourself a Data Scientist.
