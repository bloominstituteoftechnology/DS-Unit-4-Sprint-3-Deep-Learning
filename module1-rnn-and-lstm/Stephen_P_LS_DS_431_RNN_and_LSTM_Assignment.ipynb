# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Apr 23 02:37:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# I'm running with the example from the Keras website, which I discovered the
# lecture notebook copied almost word for word. Stuff is complicated and I
# I imagine for this in particular there are only so many ways you could skin a 
# cat.

from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import LambdaCallback
from keras.utils.data_utils import get_file
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense 
import numpy as np
import random
import sys
import io

path = get_file(
    '100-0.txt',
    origin='https://www.gutenberg.org/files/100/100-0.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 5573152

# %%
chars = sorted(list(set(text)))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 1857704
# Vectorization...

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)

model.compile(loss='categorical_crossentropy', 
              optimizer=optimizer,
              metrics=['accuracy'])

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 14514/14514 [==============================] - ETA: 0s - loss: 1.6483 - accuracy: 0.5088
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "r,
#     to england's king in lawful marri"
# r,
#     to england's king in lawful marriage.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "r,
#     to england's king in lawful marri"
# r,
#     to england's king in lawful marriage be hence in the plount.
#     and then i am the some not thy severed
#   to an worthy delight for the least and her,
#     have tell thee with her pride your shames,
#     and the rosaling some offence, and her mirth on his honour love a streng.
#
#                                                                                                                                                         enter
# ----- diversity: 1.0
# ----- Generating with seed: "r,
#     to england's king in lawful marri"
# r,
#     to england's king in lawful marring miching,
#     of raintain to before the sound and north,
# i have visquaded caanishs, as lees this.
#   first helme. heir not see this toath thy high honour’d forting,
# that a vement with the should that i resubtail!
#
# falstaff.
# my lord. ay, batforr. he should force ald yet did pomple have the captants action,
# mi’wn ta, i two surwarlechit' connawod'd.
#
# alfitns.
# do as your visy—
#   citizen. my fear infa
# ----- diversity: 1.2
# ----- Generating with seed: "r,
#     to england's king in lawful marri"
# r,
#     to england's king in lawful marritce but the cary.
#
# polara.
# hew gruce yours, to, thy monic friend duke
# not prass'd anad of commot mourn; she rousal yonculy dis.
#
#   alesandemded. o; is, rolabraus in barrey; governh not be sem, may fights prormed. iw, my dieed whendauding this?
#
# so? the sanus, i old,
# to onces wither, alfflmhford told, rava is'me; i resse, and bagius, or huslives, busincusk agaaay fmieis'sly,
#     and or a deelatets,
# 14514/14514 [==============================] - 137s 9ms/step - loss: 1.6483 - accuracy: 0.5088
# Epoch 2/60
# 14514/14514 [==============================] - ETA: 0s - loss: 1.5177 - accuracy: 0.5443
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " faint for
# want of meat, depart reeling "
#  faint for
# want of meat, depart reeling the bear,
#     and the beauty of the part and the street
#     and the poor the father of the bear the heart of the boyest means to the state.
#
# ----- diversity: 0.5
# ----- Generating with seed: " faint for
# want of meat, depart reeling "
#  faint for
# want of meat, depart reeling a lady and a forver with the bearing and state of the pretty friend of sure
#     the fears that say a beast, the bastled madam.
#     i do not hear him have a fire. the parts,
#     the hence and the last with him to his love and the black.
#
# posthumus.
# theref
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
# ore thou art the court of the lead and thee,
#     the most noble save her strate the blood of his death.
#   an are enfoul of the bloody news.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " faint for
# want of meat, depart reeling "
#  faint for
# want of meat, depart reeling of ream's bask of the tongue,
#     so, bishop no more so speak in the orm,
#     aud-sluck of as you have weep hear but fleac in other
# than i shall not speak the fiewnon so your grace?
#
#        enter basholy,
#   then. follow the farmiation, here hide her secred very a truel; for sir,
#     be not senncisal it thrats to raved.
#     this is stong and him wence to the crotase;
#     of foul fast, a bad. what s
# ----- diversity: 1.2
# ----- Generating with seed: " faint for
# want of meat, depart reeling "
#  faint for
# want of meat, depart reeling revolul'y thing.
#
# falstaff.
# let hyate, lest prarys. weeple of an thangta,
# marry belive me, naysted them?
# _it dare home, tell; by an head of from you try
#       breaster would. luceius. sorrow a humous puroum are further's vaturisan.
#
# nistot.
# whatks ticks to you latewo excellaclest is  morement.
# how he havest kill’d thee awny fit dreatiyal?
#   brutus. hats i'll take in nature, put wing, for eully ant
# 14514/14514 [==============================] - 198s 14ms/step - loss: 1.5177 - accuracy: 0.5443
# Epoch 3/60
# 14511/14514 [============================>.] - ETA: 0s - loss: 1.4943 - accuracy: 0.5503
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: ".
# o villain, thou hast stolen both mine "
# .
# o villain, thou hast stolen both mine own life of the sing and the part of the contents of the present and the state.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: ".
# o villain, thou hast stolen both mine "
# .
# o villain, thou hast stolen both mine own which to above thee i of the words,
# and she was in the man of a hote.
#
#  [_exeunt death, madam, good another own sent
#     of my life to thee of my sire, that speak thou art with thee.
#
# ----- diversity: 1.0
# ----- Generating with seed: ".
# o villain, thou hast stolen both mine "
# .
# o villain, thou hast stolen both mine own humanio no spiriles.
#     bulnle is
# ogenness, which they assurs with to himself.
#
# seton.
# yet ure proonts. wockour meamac quest son!
#     anotmmen. good lordde.
#
#                                                              lorenaio against that love in
# that hand no jain and take wake’d, it pro’tme endure
# tobbest -bucking fight, my poy! where trust?
#
# so, maent, schol ruled cost op them break'd,
# an
# ----- diversity: 1.2
# ----- Generating with seed: ".
# o villain, thou hast stolen both mine "
# .
# o villain, thou hast stolen both mine fexom
#     as tramio kneck peremes i know non, he since
# told theat ran, found free sile, you cact when
# that absetable no.
#
# stabs.
# let within minatius.
#     therefore thom and speak 'tis spokes,
#         is read urge. like narc!
# lead, which anynoushect, and wife
# fall’t and ownn be harrow our gid
# that shair tyny have is my crodk,
# i have no futosous sking to spire riffetu.
#   dampy than a hallmen have wr
# 14514/14514 [==============================] - 136s 9ms/step - loss: 1.4943 - accuracy: 0.5503
# Epoch 4/60
# 14513/14514 [============================>.] - ETA: 0s - loss: 1.4912 - accuracy: 0.5528
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "nd banishment is here.
# [_to cordelia._] "
# nd banishment is here.
# [_to cordelia._] and the sent and servant of the heart the body the strengtion that he will not the dear the world that the world and be the country of the stranger and so be the proper the country that she shall be the courtesy.
#   marchest of the strengtion of the company.
#
#  [_exeunt with the streams.
#
#           i sent the lears and see the prove the street
#     the bearing and sure in the compasses and sure and s
# ----- diversity: 0.5
# ----- Generating with seed: "nd banishment is here.
# [_to cordelia._] "
# nd banishment is here.
# [_to cordelia._] then we prove from the sirt on him i shall stear upon the for your princes before him fleers on my black
#     with the father's throne stand and kings.
#
# marchom.
# what doth day to this men and that i be gone and sent the here is the street
#     the suit sure and make the thou to your present the seemer the thoughts,
#     when i shors and seal the maid is my greater;
#     the summord that i do a
# good ga
# ----- diversity: 1.0
# ----- Generating with seed: "nd banishment is here.
# [_to cordelia._] "
# nd banishment is here.
# [_to cordelia._] wear these albeausted anemasters!
#
# macbeth.
# by the any, incustet’s most arh roan’d, she will not
# will prove a ngreen ndeas attend then passe whose mother toward on,
#    he yars ruseh there, sirg! royal voics, pads, an,
# doe pope, as they pace, something, let's feff too’ing
#   as the lady honour
# of thy stay'st arwick.
#
#
#                     o!
#  _gruct me him, tis of the shams, your mysell
# your silts fo
# ----- diversity: 1.2
# ----- Generating with seed: "nd banishment is here.
# [_to cordelia._] "
# nd banishment is here.
# [_to cordelia._] hath a ciscorerdest here's wepprouder’t,
#
#                  -    [_resu . i base as him. good offecmonts were oestow
# to doth feesh and heare thine
#
# bthufe! is means, which must i by head, it is her sire, formenio.
#   king richard. we muster timle, a’ll, hignftlrment
# when once a
#  lice, heer; alike hencepered here's
#               , my natecter? like thou
#     touches is withou hand his seen these
# 14514/14514 [==============================] - 137s 9ms/step - loss: 1.4912 - accuracy: 0.5528
# Epoch 5/60
# 14513/14514 [============================>.] - ETA: 0s - loss: 4.1215 - accuracy: 0.2722
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "e the fair conceit
#     the king hath of "
# e the fair conceit
#     the king hath of  thete
#       t      t _o                  tia
# ----- diversity: 0.5
# ----- Generating with seed: "e the fair conceit
#     the king hath of "
# e the fair conceit
#     the king hath of w
#       r poe nin  f lae   a ndod e onnd:
# f te s    e        bainthneohhe  rinda ou an  a te f l anis tharen w then onacod slehe ia o  ssur whl r a   garn. sndis w  e  bon t tou ea ?
# a  dhou
# f, a  e p thesndo thesg wis  toust              tex        i e h t   ie ae l   h    pothe shon or t t e   ou t   a  wa
#    hos  texmd    wo t   ho t _ir oude
#  e         eco   tilolu  no  fo eervou dhe :dath
# ----- diversity: 1.0
# ----- Generating with seed: "e the fair conceit
#     the king hath of "
# e the fair conceit
#     the king hath of isre  or ne rini kd ‘t da c. oof : oorurso c tbohle t tithenrqefo injen na gleny.
#  ipri   n ahe
#  pe
#  y  tnhifm ou ie achnouthro palteef uso -thaneask o al ire le thaut
#  itsoreefaty  etescya ooi bfsd o igu wd vimrenergethlet ts vdstlfaty
#
# ointniditamu
#   bali fextg bme fnos  ch.
#
# winihon igs ineodotari ut  kem guolan silml t eapd sia wi
# to htas e. noolus  t soayel  h
# n i lg ofdaburha  s  at m ioth
# ----- diversity: 1.2
# ----- Generating with seed: "e the fair conceit
#     the king hath of "
# e the fair conceit
#     the king hath of nne eapeteriuenihor
# ai uddera.
# mphass;ntd nhelavednouneseedf,o, ypisd
# h regesnhgo,rke;
# s t ce  vnpmy a_ssfn  thhyd wi
# oeenepftoqe e goe t ytatteherohgglik tyspemy
#   .hs wet  mf totim
#  heof;yo
#  fu   teh' vicsti,d. dwsht s eyy r;
# iko fnor nccgys.awoefm
# gn pe,at
#  r s s pomlin
#  khep gedadto e bausftluih,?ufai.m
#  p.,ntil k,
# egha.. nconani.y k pd]oed tths iy me piten.h
# pu ne
#
# re.athlraug  npoirs  bcee
#
# 14514/14514 [==============================] - 137s 9ms/step - loss: 4.1215 - accuracy: 0.2722
# Epoch 6/60
# 14512/14514 [============================>.] - ETA: 0s - loss: 3.2751 - accuracy: 0.2128
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ld not blot the letter
#   with words, til"
# ld not blot the letter
#   with words, til          ao tho    th t    ee   o         the      fa tee   oo   an_ o         t  o  f   f                                                         a  the e e                o   ano s           e    a a hee                               the    t             an  t nousth thi   thann  ow e             t      o  e              on  o                   s  m a        th                       h  an    th
# ----- diversity: 0.5
# ----- Generating with seed: "ld not blot the letter
#   with words, til"
# ld not blot the letter
#   with words, tilo thi o  m      me
#      adno  d ti t o i t s n  ou of hed iyron eb thh
# b tar  y
# hhso is.   a werd  whoe
# boohe andaf se    t  ean vy the  t amenailonors then wnrent   a alntheo
#  d  hhorote baes wou oloy
#  h  f r ai a    of  t thet.    eon  all  et t te  le w   mo    ot        b s io o weuen  hsno i s      a  t
# a  t le   i
#      fo
# ny,etlh aon snee go r orru st yane  eo thtethet thol aloendn t
# ----- diversity: 1.0
# ----- Generating with seed: "ld not blot the letter
#   with words, til"
# ld not blot the letter
#   with words, tile n ; o kwgv hd o ak l.h;n ?  thsa ba s hal
# k i erhe .edc d sa and  bsay ao.ouem woutles.
#   p  ewo hypapk,a cu itiike eoborinen 'hyd obe acl oms itntaro thawerve  ist
#  ggre n ,
# ho  fist haky sa it gt;r ylodeco  aid ia,fl  by ho 'br.ro rddrherhua  ofenwr
# rr peranvnaos.uu,
# oupt
# s;nhileteofse ’tashet r na dekiue inl   n  b.!ychdy srh  s asentlteo
#  ac toaos.
# mfe o fhsngrmn
# mre
# f rnt tee sst ajgurde e
# ----- diversity: 1.2
# ----- Generating with seed: "ld not blot the letter
#   with words, til"
# ld not blot the letter
#   with words, til caredh
#
#  ornsiueutleoenablat
# i'r oy,anton f  es aiovat.s[thnslwi
# meldfonos
#  v obnoenow rthct n;.lt td’r??ersutcfpp,e ynoge!s os lamepesnanlane
# ’ nwl
# vd,
# bbns
# nmer otecndsbrr s noe
# ifdbgeinay to. rerenwen-gnims dtrhdn n??rsa
#  conenst,  r af etwosok sovs. drleyge’o,ftuauooby
# weysiom  ntuow
# i ofnre r.]te ais ke wwyn  bgtal sha dartithnrndantle
# , lta o v’hokat gg,rbftadide  lke bt en
# hut  pt  arth
# 14514/14514 [==============================] - 137s 9ms/step - loss: 3.2750 - accuracy: 0.2128
# Epoch 7/60
# 14512/14514 [============================>.] - ETA: 0s - loss: 3.0839 - accuracy: 0.1994
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "s darkness.
#
# clown.
# fie, thou dishonest "
# s darkness.
#
# clown.
# fie, thou dishonest t                                                 tha   th    t  a  th            ot      t   h    ho       h t                                             no     t   anan        at                             t                               to          of to  to   aot t                        a mat                        o     t  at     and a    h         t
#
# ----- diversity: 0.5
# ----- Generating with seed: "s darkness.
#
# clown.
# fie, thou dishonest "
# s darkness.
#
# clown.
# fie, thou dishonest  an   ao  af mr  gh    an sa      l   o  a   an at   t cod h   f m md o  b  kondee           rh   t thtt  h   t  f m nh   f     atat t     ma t m   n
# s ouryt   n        t    o   n  hh m mr  m atha  cant w mnfr   gom   an f   ch t ma ad ti
#  mtal      lo h    ti tt m
#               y oth mas  ws haotytt ht        toena    wrn m
#   ot   tanhs
# y aanoel to  s  tnathos tan    ato e  ha  an t  ou am
# ----- diversity: 1.0
# ----- Generating with seed: "s darkness.
#
# clown.
# fie, thou dishonest "
# s darkness.
#
# clown.
# fie, thou dishonest to
#
# ecws
# senarngo  cmmemedatnwr  s   ou  ianee.
#
# yta d cnhratr  wdb dou tn aiw kryms.  secoa p ,eia oten h t bon vom dol ili fstaand  tomn thpae  hbi d s  n pedehai.h
# g tuqaone, fiad dt w fho,rnoe,,
# at.
# ag r  r crodat   wasdhous  d   m hmane. lowdoeto
# marodv.som
# uohnd;ssrmha tthga ab at.,
# str thato.
# roand maleataihnrortt frio,t  d anlleoi s wy,tr;een.ur’d e t ,geer s emet m f larithif
# i wf’ ouni
# ----- diversity: 1.2
# ----- Generating with seed: "s darkness.
#
# clown.
# fie, thou dishonest "
# s darkness.
#
# clown.
# fie, thou dishonest dbbi.cadexc  gcaapt
#
#  ematsroealht
# ftnhndge a ow
# deve hd  ee wa k,-o, tomn
#  gu hat, aanw, a
# a y aoe omo hin.
# uanno tognsasmedd.  adtrtul tassi et'yc
#  eyri sanhnosf homn ato  p yr subanal mal hhescpdmi ft
# nnmrth.wf
# w.
# erm!nhdnay s ssanr o ilan.
# deckne
# add,
# tae  soupnhlafmiml;scnco  ho snyt baisms  m boa ercdirorasho  rdarlinituadymar  tnote ndonn oob,rh   duadt kk sif i s  e,ar odadnarh
# lfs bhkmecm
# 14514/14514 [==============================] - 137s 9ms/step - loss: 3.0838 - accuracy: 0.1994
# Epoch 8/60
# 14510/14514 [============================>.] - ETA: 0s - loss: 2.9927 - accuracy: 0.1967
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "s may.
#   demetrius. then why should he d"
# s may.
#   demetrius. then why should he d  o des d    t           e    iher t s  i        d  a    in  iddere
#
# t r wie            eou  wo h     i e         e ad   the u he ar  the  no  ho    ts      bsiner   riin t  te thed e   n                          h                     a    a     s  i. t   o  a nde t    a isd to n  hi th           er       i     a    ai tine   d  t  eted ur t  ert e t ane s        i                i  t s  h
# ----- diversity: 0.5
# ----- Generating with seed: "s may.
#   demetrius. then why should he d"
# s may.
#   demetrius. then why should he d  sbdes gts  d.eeet otdo b,usr iedr  oird
# ose gan
# eint  oenrrsats s'eininstere  t te wesestse_r  itcee its so
# sn  ita
#   ewtrre b d   ibtwhe   cuse t ordels  aro ho  teeease be   at, ii  u fati  prtn thee lou iru
#   t ererb  io  epte otof  thees
#
#
#     , e  o o fiee do
# riten  tharittnrhe d wa  ls
#  r   aiogte ah sorilihuaner at s a f
#  gelleu esn     arw tinebee  t rof   is ui    tesenh threrd e
# ----- diversity: 1.0
# ----- Generating with seed: "s may.
#   demetrius. then why should he d"
# s may.
#   demetrius. then why should he d.antiaooo fitex
#  eabent iadcksuiervls hifrr
# me;rrmdk u
# egnd eouf. ar
#  redipa moo  en.ueum lcme oso any w.
#  fir
#  t.co
# .aps me edlore b o  udf me r e hgep
# rc tto thr mh   yorru irtlelraaovhor
# t
# ncasfnysert wrg
# tda a rnd t
# i yaono ayf
# i
# usfh e efige
# d m isanexrd.wyc,idc,
#  in tenthourg
#  n hr fi fhd unfmeafivwademnu m drcgrwthneen,hnifrit aeasi.rlme sats.wirof ywnedisu.bardu ,, gtyfrai snonmarof bi it
# ----- diversity: 1.2
# ----- Generating with seed: "s may.
#   demetrius. then why should he d"
# s may.
#   demetrius. then why should he drtfdeygowinps  o umrec  w..tuimtmmd?a
#  awotofdthfis bspneingo usoisa umpisewde b ov  a ca ' arvoe heeundstieerd i he pc.uder mei  rssb  tais,vdstralasdnputistlnwatcbonwviodg
# e ssed,.e rt.hwyshr
# edesoalhdon!eie.mi
# sd.ahs,pyre.cfw
#  frasme an.trteixee dggd.oeed wwo'
# tod wlrai..
# eralgdrl!o  l,rh.shilmuai, wn nn aso ast b,taer rubvkt m?vofymno,?yasci-usn
#  aigosheadgb uim ’
# yr m adiuea,  xwc t.a  lsm
# 14514/14514 [==============================] - 138s 10ms/step - loss: 2.9927 - accuracy: 0.1967
# Epoch 9/60
# 14511/14514 [============================>.] - ETA: 0s - loss: 2.9943 - accuracy: 0.1944
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "and if we be, how dare thy joints forget"
# and if we be, how dare thy joints forget   w       w    w       to      e          t   t  t   t                  t    to  te  t       s       to      tn et  wo e             te  t       t                 t        t th        e                 t     d  the t    he   t      th        t  the   th    f  e   t         t     th   t t    t te  we nn        t   t te  t thele        h  l  to w  o          o            y    to      th    d
# ----- diversity: 0.5
# ----- Generating with seed: "and if we be, how dare thy joints forget"
# and if we be, how dare thy joints forgethhe.
#  w he a a ghit at
# sirht
#     w d iot
#   o yn     hetw   es  eo   t  te,be g  th wtsae e rie       ors  at bit t  w     s ou t
# i wato toto  to  mi
#  wadoo  n   l  bl
# w od
#  hr   a   t t   th t we   t w weylne mt  r w   th    a   y an nanatre,ra t n   thd     w trte    ees y  olet oa s  mh d  at  hat   g  oo yneirt  a y e tt   one
# fet u  e mw  lat in    is r nds  o  h s   ee n  n to
#  io at entee
# ----- diversity: 1.0
# ----- Generating with seed: "and if we be, how dare thy joints forget"
# and if we be, how dare thy joints forgetryon
# n  lst e na  frne; r saunsrueopelteayd sfu
#
#
# ea pom    y te
# t  gesfr m sntimeee.ileddn.oure  teo
#  yrorvt  fmltl!b fr  loasyr fo thadiyot?rho
# ei.
# drrdit,m fioda  w lhcg
# mieate ty toinntler eiseauh wepslydsioefh g  alo
#  nt;egno, ]la   erat
#
# iklt bomuoe el tsdole t
# ylceorinss tmd ea
# yog iooaw]
# trconn  ltlotngmil tarrr   .kchtotory wi b tti   lvtrye .wnatw  i en enilwh*wset
# -oma
# do tweood lt
# ----- diversity: 1.2
# ----- Generating with seed: "and if we be, how dare thy joints forget"
# and if we be, how dare thy joints forgeto ssdlk edls.erok.totdnottouyrdl-kfn,dt murg,helug.
# ugafgnadukt.
# atnigaoyfl
#  an ji e  tt f,trrln t. fed u tieu otpy._s sh t mt,fm.ned pthowin bowo   homhrtwnd .y amelga or ddvu ukl
# t g!chos, t mhl r k lpfh
# gttvfbdiin mip l
# htedw iuml beyht  gnould wu aaip- c
# ha.
# hgst  wsnenmgu ksg mlis
#  l efhelrnsygyr t,hteylide
# fwsovt-m het,,
#    hitfeln ,
#
# it tuo nfm sh cyednycienek h,gut
# m t
# lnshrapigee
# bnit
# 14514/14514 [==============================] - 138s 9ms/step - loss: 2.9943 - accuracy: 0.1944
# Epoch 10/60
# 14507/14514 [============================>.] - ETA: 0s - loss: 3.0078 - accuracy: 0.1945
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "th the broken seals of
# perjury; some, ma"
# th the broken seals of
# perjury; some, man th     a                 a              ao          t               e     to a      a      tt  a     oo t             aaa   t    anea    aa      h   i    o    ann me      t      oo  o      an         l    t   o    h   a        ar     l        oa    a         le t   h       e     an   a        a            t         e    o a       a   hee  ane   a  he  aner ar        t      he  s   a       a
# ----- diversity: 0.5
# ----- Generating with seed: "th the broken seals of
# perjury; some, ma"
# th the broken seals of
# perjury; some, ma  aw i mgoeon lser ns  oenn o d  o  ohare a leun  manceuh ttroy ar   tt at  n thatr  io,  i ao u
# hrer .o  t a  d i
# aile asrln    an      ale   h     s wantaoweea es  mniele annr    dase thages e  ae  fdr yoe  sr  as     om trerh   e  t ee    t
# sicee  dd
# a thet i tlhhen
# led h d eh
#  o   weel sas tt   i  lo   h     w     r, bady  aao  ntee  ah  aiaok      hol c p t ntea
#  t  o wahat eihan s sis
# ----- diversity: 1.0
# ----- Generating with seed: "th the broken seals of
# perjury; some, ma"
# th the broken seals of
# perjury; some, mae ws sh h tmrrl ,n,
# mawustorr iotinh h rntigldn
# eknrh ai .nme s bannhio!t;sm
# ire
# a
# inccme m ane
# cgk l  ; ew
# o hfn wlert
# e sit,
# nl d avtaee  pi ihe ft intfoof m tenflsse?
# od f  aa llsll  wiraary  wonenh
# t  th vd  r hhooh
#    ae e.lk.e’ecd cr esu
# t e naatanornsrtvwlai ,ilbo , alv’
# a bed tt
# eanc  th lo   oo h y s
# coenlrlelootacmree,t
# lfmt,  sn
# s hna  ll yu
#  o t br,oheondm  te tokdohr?od fhtw ua
#
# ----- diversity: 1.2
# ----- Generating with seed: "th the broken seals of
# perjury; some, ma"
# th the broken seals of
# perjury; some, mat  msiyspe\on;fdo,ai,l qhphs sabfgniaad
#  asscoge,bdu,i o ecm ns .cde daus, yhashn t ; onri tme a
# hi  m iita oywh,es
# ex nts swiguvygomfasawrn,r;  nn liayoansg rtbe antoanou,
# d
# ,mdm pstnihlasfenepdtn
# eu   nf te dgh
# m syyor olndi!ew_waassr iaun
# deepntltevetfb,frs tnpse nhkei ehareytmddrof o t
# hwt
# dd lthckneiie tc
# thslrt.a
# hhd ngomb  ht th
# es nio-dottsa_g ttmhhesr
# t  eopl nno:teitiudel yinoodyeoaco  e
# 14514/14514 [==============================] - 138s 9ms/step - loss: 3.0078 - accuracy: 0.1944
# Epoch 11/60
# 14510/14514 [============================>.] - ETA: 0s - loss: 3.0252 - accuracy: 0.1922
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "follow.
#
#
#       conrade.
#       i will ow"
# follow.
#
#
#       conrade.
#       i will ow   t    m tou t  t               t te e  th     t  t    t t      t    te im re t e            n e    u  r  u     t     tereh to    then             o ere              i     te  l  t e    o                 t                           e
#
#       n tt  o  i r t th  t    now       me
#             t t  e   t      i  thir            o   uer  u ro    t                  t e ner     e  t    t     e    u e
# ----- diversity: 0.5
# ----- Generating with seed: "follow.
#
#
#       conrade.
#       i will ow"
# follow.
#
#
#       conrade.
#       i will ow  r   to ttmur. teo   i wrvatet
# eoeou t t
#  tgrret ow l t   o,   eour o se  we ltt m
# h the mdrrler  a teseei ton  e w t  iot
#    h t  o e     e hs ee t  tth  pro  a thsiste  t i  ashhi  o ln
#  somir er t essea inhi  o s   ie     gtestt eo to i ainhsa  ereea p e mw  ite al nat  nn  t  ros en e me sit   ere g   w oo av  t
# ee ee tuuss trs  r  t ttee  re se      teure uid  rst  o rk  gt  ier    n t m
# ----- diversity: 1.0
# ----- Generating with seed: "follow.
#
#
#       conrade.
#       i will ow"
# follow.
#
#
#       conrade.
#       i will owadirgid
#  uiac
# th
# a gfroy mtnh m,e v a  uyrf'nwr yeo
# -sloaninc
# evewotimeins
# ,htositutie n sgrmrt
# eth ltfhjoerwliu.l t   fbeatm t e nnvit  rit l, 't d diet  bhetouilsi ioer, ile sata uoi  nlree
# to eogavnwin
# ’d t  [odeeou
# ggli rrinnn ahth.nhoat onh t lu vg ooug.l,d ren mnr
# e a.
#
# astr eriu nt syplte pc me t bsit eu cs
# i oi
#  rath.eeaae, ec la  sits dtmifertr’rteldr
# nvtt irvg, gti
#  ffmsr srsat
# ere
# ----- diversity: 1.2
# ----- Generating with seed: "follow.
#
#
#       conrade.
#       i will ow"
# follow.
#
#
#       conrade.
#       i will owntay.almernmklrfaouopt  ypnt
# byaye?v?
# gec wreaeup a
#  tmd oao sarud:owri  , pwl dleca  roriorsnn tdtgerw,igseehs g l
# ude tohmnxru, id a ciwi't.  e a tayft,drt fi
# htalalnnyhiaveiete
# e'cn? rrtes  nvlainkfhmwirooueabf donhav , t.vosh wr
#
# r h l tvasoournmun bsdte  brd tolutiie uu mf i,r
# unti
#  nbowc,ui hoo
# af sarcr s cositvein tanm.. vr me ihcoh nuiemrestai. s]
# rstof thimieisriieeen.a lr,teew!t ns
# o w
# 14514/14514 [==============================] - 138s 10ms/step - loss: 3.0252 - accuracy: 0.1923
# Epoch 12/60
# 14509/14514 [============================>.] - ETA: 0s - loss: 3.0336 - accuracy: 0.1920
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "e friend,
# let me embrace thine age, whos"
# e friend,
# let me embrace thine age, whos           a f                n          o                    to      b                                       t                                       he  e         ea           to  o  th            t             t   e    th       f o       n      r                                  o       o                 x      to     t                   o f        t o            t  e     o    n            u
# ----- diversity: 0.5
# ----- Generating with seed: "e friend,
# let me embrace thine age, whos"
# e friend,
# let me embrace thine age, whos f   aont i  tne  f   es   d ostu
# rerie t”u sm  s m tet
# y fro   feie
# it i   twu t u    thdh i  t t  eoi   o  t at no
# t      mo  ao       rh   m  mssta   f   td thap  i on ter io  ro lc   s   f    n o n w no tt ild    t ry ottie ie moou ttoo  ou a   t   oin t
# elan e r e     l  to eend su  te  o  n ll  csa   a   o  c ou  nho o   isne d i’    e t     ai oh    ht      e  oo eeo rer tor nleo
#
#  r  hac
# ----- diversity: 1.0
# ----- Generating with seed: "e friend,
# let me embrace thine age, whos"
# e friend,
# let me embrace thine age, whosgke trie
# e,
# ..oio  .nu  s, t thrt .tor
#  ’c od.
# otitir u,  t e bwto t pbaetetpoenn’oc
#  sott  pstionc debmns,lldtt ot peoe  r rngudottlirs,  ni t’atwveallf  llekatht
# iis arnn n  is, c hhalatft?strmonse.m  oosox rt acio
# otmtaat'  def  ncfeel wanrdireruciyantn m mwy ftboi.
#    o
# vste'adw
# epil
#  seoiuhtif ac rscsinn eerwda  baareohibtt
# ’tptc tmt w in.rf n no w s.u nl en rruls te omtdlotusivoegn hat f
# ----- diversity: 1.2
# ----- Generating with seed: "e friend,
# let me embrace thine age, whos"
# e friend,
# let me embrace thine age, whos te  iro.l d
#
# !gofrllfoebbe;ie f eeeu h
#  :s;
# sle
# simmdiwtrnrpwd,gitme se,flmfh!us;cau epe,tytolgdror'
# ito twa’s.niotaeies
# rdun
# nm
#  i
# r  sc thotmanss ypdagoiufnhyat'dolosowsue osso royrs ?
# idmntfeem
# sb,
# qnet
#
#    uei
# rout  i aclferufaom repl m.n,neb-gc
# lichld isha lnvtth ,rhormyet crt,
# e c:l mr'rotcteeecneuefirr koap bht _hth uolm wobp'  i w  um er  ssonl co:rcogg aenoo apsmpelor ponw
# ,n iu.re
# swuua
# 14514/14514 [==============================] - 137s 9ms/step - loss: 3.0335 - accuracy: 0.1920
# Epoch 13/60
# 14271/14514 [============================>.] - ETA: 1s - loss: 3.0394 - accuracy: 0.1927

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
