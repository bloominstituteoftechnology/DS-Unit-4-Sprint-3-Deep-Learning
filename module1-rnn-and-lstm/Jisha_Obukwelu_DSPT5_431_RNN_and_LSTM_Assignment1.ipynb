# %% [markdown]
# <a href="https://colab.research.google.com/github/jiobu1/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/Jisha_Obukwelu_DSPT5_431_RNN_and_LSTM_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, TensorBoard
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

import numpy as np
import random
import sys
import requests
import os
import datetime

# %%
url = "https://www.gutenberg.org/files/100/100-0.txt"

r = requests.get(url)

# %%
r.encoding = r.apparent_encoding

data = r.text

# %%
data[:100]
# Out:
# 'Project Gutenberg’s The Complete Works of William Shakespeare, by William Shakespeare\r\n\r\nThis eBook '

# %%
data = data.split('\r\n')

# %%
toc = [l.strip() for l in data[44:130:2]]

# %%
# Skip the Table of Contents
data = data[135:]

# %%
toc
# Out:
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA',
#  'AS YOU LIKE IT',
#  'THE COMEDY OF ERRORS',
#  'THE TRAGEDY OF CORIOLANUS',
#  'CYMBELINE',
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK',
#  'THE FIRST PART OF KING HENRY THE FOURTH',
#  'THE SECOND PART OF KING HENRY THE FOURTH',
#  'THE LIFE OF KING HENRY THE FIFTH',
#  'THE FIRST PART OF HENRY THE SIXTH',
#  'THE SECOND PART OF KING HENRY THE SIXTH',
#  'THE THIRD PART OF KING HENRY THE SIXTH',
#  'KING HENRY THE EIGHTH',
#  'KING JOHN',
#  'THE TRAGEDY OF JULIUS CAESAR',
#  'THE TRAGEDY OF KING LEAR',
#  'LOVE’S LABOUR’S LOST',
#  'THE TRAGEDY OF MACBETH',
#  'MEASURE FOR MEASURE',
#  'THE MERCHANT OF VENICE',
#  'THE MERRY WIVES OF WINDSOR',
#  'A MIDSUMMER NIGHT’S DREAM',
#  'MUCH ADO ABOUT NOTHING',
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE',
#  'PERICLES, PRINCE OF TYRE',
#  'KING RICHARD THE SECOND',
#  'KING RICHARD THE THIRD',
#  'THE TRAGEDY OF ROMEO AND JULIET',
#  'THE TAMING OF THE SHREW',
#  'THE TEMPEST',
#  'THE LIFE OF TIMON OF ATHENS',
#  'THE TRAGEDY OF TITUS ANDRONICUS',
#  'THE HISTORY OF TROILUS AND CRESSIDA',
#  'TWELFTH NIGHT; OR, WHAT YOU WILL',
#  'THE TWO GENTLEMEN OF VERONA',
#  'THE TWO NOBLE KINSMEN',
#  'THE WINTER’S TALE',
#  'A LOVER’S COMPLAINT',
#  'THE PASSIONATE PILGRIM',
#  'THE PHOENIX AND THE TURTLE',
#  'THE RAPE OF LUCRECE',
#  'VENUS AND ADONIS',
#  '']

# %%
len(toc)
# Out:
# 43

# %%
# Fixing Titles
toc[9] = 'THE LIFE OF KING HENRY V'
toc[18] = 'MACBETH'
toc[24] = 'OTHELLO, THE MOOR OF VENICE'
toc[34] = 'TWELFTH NIGHT: OR, WHAT YOU WILL'

# %%
locations = {
    id_:{
        'title':title, 'start':-99
    } for id_,title in enumerate(toc)}

# %%
# Start 
for e,i in enumerate(data):
    for t,title in enumerate(toc):
        if title in i:
            locations[t].update({'start':e})

# %%
import pandas as pd
df_toc = pd.DataFrame.from_dict(locations, orient='index')

# %%
df_toc
# Out:
#                                        title   start
# 0        THE TRAGEDY OF ANTONY AND CLEOPATRA     -99
# 1                             AS YOU LIKE IT   14380
# 2                       THE COMEDY OF ERRORS   17172
# 3                  THE TRAGEDY OF CORIOLANUS   20373
# 4                                  CYMBELINE   30347
# 5   THE TRAGEDY OF HAMLET, PRINCE OF DENMARK   30365
# 6    THE FIRST PART OF KING HENRY THE FOURTH   37052
# 7   THE SECOND PART OF KING HENRY THE FOURTH   41768
# 8           THE LIFE OF KING HENRY THE FIFTH     -99
# 9                   THE LIFE OF KING HENRY V   45177
# 10   THE SECOND PART OF KING HENRY THE SIXTH   53384
# 11    THE THIRD PART OF KING HENRY THE SIXTH   56872
# 12                     KING HENRY THE EIGHTH   60258
# 13                                 KING JOHN   66711
# 14              THE TRAGEDY OF JULIUS CAESAR   66784
# 15                  THE TRAGEDY OF KING LEAR   71428
# 16                      LOVE’S LABOUR’S LOST   77464
# 17                    THE TRAGEDY OF MACBETH     -99
# 18                                   MACBETH   84428
# 19                    THE MERCHANT OF VENICE   87528
# 20                THE MERRY WIVES OF WINDSOR   91696
# 21                 A MIDSUMMER NIGHT’S DREAM   94655
# 22                    MUCH ADO ABOUT NOTHING   98115
# 23    THE TRAGEDY OF OTHELLO, MOOR OF VENICE     -99
# 24               OTHELLO, THE MOOR OF VENICE  103827
# 25                   KING RICHARD THE SECOND  114240
# 26                    KING RICHARD THE THIRD  117333
# 27           THE TRAGEDY OF ROMEO AND JULIET  121741
# 28                   THE TAMING OF THE SHREW  126997
# 29                               THE TEMPEST  131871
# 30               THE LIFE OF TIMON OF ATHENS  135694
# 31           THE TRAGEDY OF TITUS ANDRONICUS  138410
# 32       THE HISTORY OF TROILUS AND CRESSIDA  141286
# 33          TWELFTH NIGHT; OR, WHAT YOU WILL     -99
# 34          TWELFTH NIGHT: OR, WHAT YOU WILL  147449
# 35                     THE TWO NOBLE KINSMEN  154344
# 36                         THE WINTER’S TALE  159532
# 37                       A LOVER’S COMPLAINT  164547
# 38                    THE PASSIONATE PILGRIM  164930
# 39                THE PHOENIX AND THE TURTLE  165170
# 40                       THE RAPE OF LUCRECE  165264
# 41                          VENUS AND ADONIS  167483
# 42                                            169307

# %%
df_toc['end'] = df_toc['start'].shift(-1).apply(lambda x: x-1)

# %%
df_toc.loc[42, 'end'] = len(data)

# %%
df_toc.tail()
# Out:
#                          title   start       end
# 38      THE PASSIONATE PILGRIM  164930  165169.0
# 39  THE PHOENIX AND THE TURTLE  165170  165263.0
# 40         THE RAPE OF LUCRECE  165264  167482.0
# 41            VENUS AND ADONIS  167483  169306.0
# 42                              169307  169308.0

# %%
df_toc['text'] = df_toc.apply(lambda x: '\r\n'.join(data[ x['start'] : int(x['end']) ]), axis=1)

# %%
df_toc.head()
# Out:
#                                  title  ...                                               text
# 0  THE TRAGEDY OF ANTONY AND CLEOPATRA  ...
# 1                       AS YOU LIKE IT  ...  AS YOU LIKE IT\r\n\r\n\r\nDRAMATIS PERSONAE.\r...
# 2                 THE COMEDY OF ERRORS  ...  THE COMEDY OF ERRORS\r\n\r\n\r\n\r\nContents\r...
# 3            THE TRAGEDY OF CORIOLANUS  ...  THE TRAGEDY OF CORIOLANUS\r\n\r\nDramatis Pers...
# 4                            CYMBELINE  ...  CYMBELINE.\r\nLaud we the gods;\r\nAnd let our...
#
# [5 rows x 4 columns]

# %%
# divide b/w plays and sonets
sonets = data[:2776]
plays = data[2777:]

# %%
data[0]
# Out:
# '                    1'

# %%
def long_lines(lst_ln):
    clean = []
    
    for ln in lst_ln: 
        
        if len(ln) == 0:
            pass
        else:
            pct = len(ln.strip(' ')) / len(ln)

            if pct >= .5:
                clean.append(ln.lstrip())

    return clean

# %%
# May Not be Needed
sonets = long_lines(sonets)
plays = long_lines(plays)

# %% [markdown]
# ## Word Encoding
#
# This is just a start, and is not complete yet.

# %%
vocab = list(set("\r\n".join(plays).split()))
words = [line.split() for line in plays]

# %%
len(vocab)
# Out:
# 75578

# %% [markdown]
# ## Character Encoding
#
# Using the technique shown in lecture.

# %%
text = '\r\n'.join(sonets)

chars = list(set(text))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

print(f"Our corpus contains {len(chars)} unique characters.")
# Out:
# Our corpus contains 63 unique characters.

# %%
# Create the Sequence Data

maxlen = 150
step = 1

encoded = [char_int[c] for c in text]

sequences = [] # Each element is 40 characters long
next_chars = [] # One element for each sequence

for i in range(0, len(encoded) - maxlen, step):
    sequences.append(encoded[i : i + maxlen])
    next_chars.append(encoded[i + maxlen])
    
print('sequences:', len(sequences))
# Out:
# sequences: 95704

# %%
import numpy as np

# Specify x & y

x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_chars[i]] = 1

# %%
x.shape
# Out:
# (95704, 150, 63)

# %%
# build the model: a single LSTM

model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), dropout=0.2))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='nadam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               327680
# _________________________________________________________________
# dense (Dense)                (None, 63)                16191
# =================================================================
# Total params: 343,871
# Trainable params: 343,871
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 1
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(text) - maxlen - 1)
    
    generated = ''
    
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)
    
    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_int[char]] = 1
            
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = int_char[next_index]
        
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()


print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

model.fit(x, y,
          batch_size=1024,
          validation_split=.2,
          epochs=100,
          callbacks=[print_callback, 
                     #EarlyStopping(min_delta=.02, monitor='val_loss', patience=10),
                     tensorboard_callback])
# Out:
# Epoch 1/100
#  1/75 [..............................] - ETA: 0s - loss: 4.1409WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/75 [..............................] - ETA: 8s - loss: 4.1307WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0790s vs `on_train_batch_end` time: 0.1476s). Check your callbacks.
# 75/75 [==============================] - ETA: 0s - loss: 3.1709
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "let past prime,
# And sable curls all silvered o’er with white:
# When lofty trees I see barren of leaves,
# Which erst from heat did canopy the herd
# An"
# let past prime,
# And sable curls all silvered o’er with white:
# When lofty trees I see barren of leaves,
# Which erst from heat did canopy the herd
# Anvb mgyss slurmotrewall huelh(rermdvuhaioiIrlcei
# r
#  th,dpt fiveaento   eirhla,svegh daoa
# msws  tIof lyTass  r
# srrIive
#  at eheetasooh  iTfsdhichl y oathhhIn t ,ftatsononc
# hes lena i  vao  m f
# t owdv  phshati irh hndea utih esnsr
# oswmg,ol usa hhrnic
#  s Te
# 75/75 [==============================] - 25s 331ms/step - loss: 3.1709 - val_loss: 3.0662
# Epoch 2/100
# 75/75 [==============================] - ETA: 0s - loss: 2.9386
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "ines of thy deceased lover:
# Compare them with the bett’ring of the time,
# And though they be outstripped by every pen,
# Reserve them for my love, not"
# ines of thy deceased lover:
# Compare them with the bett’ring of the time,
# And though they be outstripped by every pen,
# Reserve them for my love, not ehrtmo tfoos tn sm wetito,tot ghr ngaAtst eh n Wa of ,e, lioe vd,f
# nei eseeBsseweanh soWg(te,tnmeahdeoye syemtwnrhiutpth’i,o eoile m pe selo  y  bothdasY moaiwcaard,,
# o ,e
#  reoces
# Ad
# , ui ymer to cghaa tethe tiaiser
# 75/75 [==============================] - 24s 325ms/step - loss: 2.9386 - val_loss: 2.7410
# Epoch 3/100
# 75/75 [==============================] - ETA: 0s - loss: 2.6251
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "w’st I love her,
# And for my sake even so doth she abuse me,
# Suff’ring my friend for my sake to approve her.
# If I lose thee, my loss is my love’s ga"
# w’st I love her,
# And for my sake even so doth she abuse me,
# Suff’ring my friend for my sake to approve her.
# othanl,gonamd rieedbnesld  hhets rata toutt lhuke bae, iisthe kstthturiwo asng.ean  tod an wlvy rorrunSsn ootoyennk thovedvs?thovu,s,b
#  d wgotiyu ry tir tho ds uhthre B
# 75/75 [==============================] - 25s 333ms/step - loss: 2.6251 - val_loss: 2.4474
# Epoch 4/100
# 75/75 [==============================] - ETA: 0s - loss: 2.4602
# ----- Generating text after Epoch: 3
# ----- Generating with seed: " eyes:
# Now see what good turns eyes for eyes have done,
# Mine eyes have drawn thy shape, and thine for me
# Are windows to my breast, where-through th"
#  eyes:
# Now see what good turns eyes for eyes have done,
# Mine eyes have drawn thy shape, and thine for me
# o  na thawu th ld,f
# eive bh th na s pruth h ian yye aihe, ty un sitor beth sorthem thasd sank il s meu thht I  of nutelpe thotnghhrinBut-an stase yeroulises yurn nd t e cv e  ur noe wo d nn I ahrc  nom
# 75/75 [==============================] - 26s 345ms/step - loss: 2.4602 - val_loss: 2.3296
# Epoch 5/100
# 75/75 [==============================] - ETA: 0s - loss: 2.3783
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "h I bring forth,
# And so should you, to love things nothing worth.
# That time of year thou mayst in me behold,
# When yellow leaves, or none, or few do"
# h I bring forth,
# And so should you, to love things nothing worth.
# That time of year thou mayst in me behold,
#
#
#
# Th thay  ond ty bise,e
# His thce tidm,
#
#
#
# Andind im so  youns th be,a
# 75/75 [==============================] - 25s 330ms/step - loss: 2.3783 - val_loss: 2.2407
# Epoch 6/100
# 75/75 [==============================] - ETA: 0s - loss: 2.3277
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "ad interim like the ocean be
# Which parts the shore, where two contracted new,
# Come daily to the banks, that when they see:
# Return of love, more ble"
# ad interim like the ocean be
# Which parts the shore, where two contracted new,
# Come daily to the banks, that when they see:
#
#
# Yhir wodat iatllly weat bevy fiy pomkinge w
#
#
#
# Yid wh geeetat mouphort yol ingt fove l
# ais ojsta,isj ovil, Theon forrithelTaltt aw?
# wh qteachtand aasea oushang,nhtira
# 75/75 [==============================] - 25s 339ms/step - loss: 2.3277 - val_loss: 2.1929
# Epoch 7/100
# 75/75 [==============================] - ETA: 0s - loss: 2.2747
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "e hour mine,
# The region cloud hath masked him from me now.
# Yet him for this, my love no whit disdaineth,
# Suns of the world may stain, when heaven’s"
# e hour mine,
# The region cloud hath masked him from me now.
# Yet him for this, my love no whit disdaineth,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Th
# 75/75 [==============================] - 25s 338ms/step - loss: 2.2747 - val_loss: 2.1639
# Epoch 8/100
# 75/75 [==============================] - ETA: 0s - loss: 2.2295
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "e hath cast his utmost sum,
# Called to that audit by advised respects,
# Against that time when thou shalt strangely pass,
# And scarcely greet me with "
# e hath cast his utmost sum,
# Called to that audit by advised respects,
# Against that time when thou shalt strangely pass,
#
#
#
#
#
#
#
#
#
#
# And byat loms putkeoot,l
# Pouad,
#
#
# For beatt tha
# 75/75 [==============================] - 25s 331ms/step - loss: 2.2295 - val_loss: 2.1308
# Epoch 9/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1984
# ----- Generating text after Epoch: 8
# ----- Generating with seed: "on or quick change?
# Why with the time do I not glance aside
# To new-found methods, and to compounds strange?
# Why write I still all one, ever the sam"
# on or quick change?
# Why with the time do I not glance aside
# To new-found methods, and to compounds strange?
#
#
#
#
#
#
#
#
#
#
# Bue ,
# 75/75 [==============================] - 25s 339ms/step - loss: 2.1984 - val_loss: 2.0780
# Epoch 10/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1733
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "e thee more:
# To keep an adjunct to remember thee
# Were to import forgetfulness in me.
# No! Time, thou shalt not boast that I do change,
# Thy pyramids"
# e thee more:
# To keep an adjunct to remember thee
# Were to import forgetfulness in me.
# No! Time, thou shalt not boast that I do change,
#
#
#
#
#
#
#
#
#
# 75/75 [==============================] - 25s 332ms/step - loss: 2.1733 - val_loss: 2.0455
# Epoch 11/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1500
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "leasure of the fleeting year!
# What freezings have I felt, what dark days seen!
# What old December’s bareness everywhere!
# And yet this time removed w"
# leasure of the fleeting year!
# What freezings have I felt, what dark days seen!
# What old December’s bareness everywhere!
#
#
#
#
#
#
# But bes part etun aonbyed sels do hame s
#
#
#
#
# I  avei e
# 75/75 [==============================] - 25s 339ms/step - loss: 2.1500 - val_loss: 2.0292
# Epoch 12/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1296
# ----- Generating text after Epoch: 11
# ----- Generating with seed: "
# But ah, thought kills me that I am not thought
# To leap large lengths of miles when thou art gone,
# But that so much of earth and water wrought,
# I m"
#
# But ah, thought kills me that I am not thought
# To leap large lengths of miles when thou art gone,
# But that so much of earth and water wrought,
#
#
#
# O thef fimh note busd bite bond bing
#
#
#
#
#
#
# Nor eaye, thon alls, frof,de
# 75/75 [==============================] - 25s 336ms/step - loss: 2.1296 - val_loss: 2.0047
# Epoch 13/100
# 75/75 [==============================] - ETA: 0s - loss: 2.1071
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "won,
# Beauteous thou art, therefore to be assailed.
# And when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
# Ay me, b"
# won,
# Beauteous thou art, therefore to be assailed.
# And when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
#
#
#
#
#
# With erought beracrdea p’er, de uel me y
#
#
#
# Ahonghate seactl
# 75/75 [==============================] - 25s 335ms/step - loss: 2.1071 - val_loss: 1.9978
# Epoch 14/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0946
# ----- Generating text after Epoch: 13
# ----- Generating with seed: ", nor stone, nor earth, nor boundless sea,
# But sad mortality o’ersways their power,
# How with this rage shall beauty hold a plea,
# Whose action is no"
# , nor stone, nor earth, nor boundless sea,
# But sad mortality o’ersways their power,
# How with this rage shall beauty hold a plea,
# Whose action is not shoo sealiss owithe weas::
#
#
#
#
#
#
#
#
#
# Lalle phit whtt whill white as
# 75/75 [==============================] - 26s 340ms/step - loss: 2.0946 - val_loss: 1.9814
# Epoch 15/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0738
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "same,
# And that unfair which fairly doth excel:
# For never-resting time leads summer on
# To hideous winter and confounds him there,
# Sap checked with "
# same,
# And that unfair which fairly doth excel:
# For never-resting time leads summer on
# To hideous winter and confounds him there,
#
#
#
#
#
#
#
#
# Ald I cored if thy gonthengs,s
#
# I mio shave t
# 75/75 [==============================] - 25s 336ms/step - loss: 2.0738 - val_loss: 1.9610
# Epoch 16/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0625
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "ve,
# And thou present’st a pure unstained prime.
# Thou hast passed by the ambush of young days,
# Either not assailed, or victor being charged,
# Yet th"
# ve,
# And thou present’st a pure unstained prime.
# Thou hast passed by the ambush of young days,
# Either not assailed, or victor being charged,
#
#
#
#
#
#
#
#
# Thacs nn eis sown cnme rate
# 75/75 [==============================] - 26s 341ms/step - loss: 2.0625 - val_loss: 1.9448
# Epoch 17/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0484
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "ed
# From this vile world with vilest worms to dwell:
# Nay if you read this line, remember not,
# The hand that writ it, for I love you so,
# That I in y"
# ed
# From this vile world with vilest worms to dwell:
# Nay if you read this line, remember not,
# The hand that writ it, for I love you so,
#
#
#
#
#
#
#
#
#
# Whe uees afthis sheas h
# 75/75 [==============================] - 25s 333ms/step - loss: 2.0484 - val_loss: 1.9309
# Epoch 18/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0348
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "with this rage shall beauty hold a plea,
# Whose action is no stronger than a flower?
# O how shall summer’s honey breath hold out,
# Against the wrackfu"
# with this rage shall beauty hold a plea,
# Whose action is no stronger than a flower?
# O how shall summer’s honey breath hold out,
#
#
#
#
#
#
#
#
#
# Tht I me
# 75/75 [==============================] - 25s 335ms/step - loss: 2.0348 - val_loss: 1.9186
# Epoch 19/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0195
# ----- Generating text after Epoch: 18
# ----- Generating with seed: "r every blot,
# And all things turns to fair, that eyes can see!
# Take heed (dear heart) of this large privilege,
# The hardest knife ill-used doth lose"
# r every blot,
# And all things turns to fair, that eyes can see!
# Take heed (dear heart) of this large privilege,
#
#
#
#
#
#
#
# When shaplist all weib pratst, you
# 75/75 [==============================] - 26s 342ms/step - loss: 2.0195 - val_loss: 1.9122
# Epoch 20/100
# 75/75 [==============================] - ETA: 0s - loss: 2.0066
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "went wilful-slow,
# Towards thee I’ll run, and give him leave to go.
# So am I as the rich whose blessed key,
# Can bring him to his sweet up-locked trea"
# went wilful-slow,
# Towards thee I’ll run, and give him leave to go.
# So am I as the rich whose blessed key,
#
#
#
#
#
#
#
#
#
# Wite thy, fro sume with hi
# 75/75 [==============================] - 25s 334ms/step - loss: 2.0066 - val_loss: 1.8968
# Epoch 21/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9972
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "ood, in thee it is abused.
# I never saw that you did painting need,
# And therefore to your fair no painting set,
# I found (or thought I found) you did"
# ood, in thee it is abused.
# I never saw that you did painting need,
# And therefore to your fair no painting set,
#
#
#
#
#
#
#
#
#
# Nor ave thy
# 75/75 [==============================] - 25s 336ms/step - loss: 1.9972 - val_loss: 1.8886
# Epoch 22/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9839
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "
# The one by toil, the other to complain
# How far I toil, still farther off from thee.
# I tell the day to please him thou art bright,
# And dost him gr"
#
# The one by toil, the other to complain
# How far I toil, still farther off from thee.
# I tell the day to please him thou art bright,
#
#
#
#
#
#
#
#
#
# Wiine mprearsif srewri
# 75/75 [==============================] - 25s 331ms/step - loss: 1.9839 - val_loss: 1.8793
# Epoch 23/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9720
# ----- Generating text after Epoch: 22
# ----- Generating with seed: " times happy me.
# How can my muse want subject to invent
# While thou dost breathe that pour’st into my verse,
# Thine own sweet argument, too excellent"
#  times happy me.
# How can my muse want subject to invent
# While thou dost breathe that pour’st into my verse,
#
#
#
#
#
#
#
#
#
# Lode love ’or dous saitedun saal tim
# 75/75 [==============================] - 25s 328ms/step - loss: 1.9720 - val_loss: 1.8693
# Epoch 24/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9582
# ----- Generating text after Epoch: 23
# ----- Generating with seed: "r men discased, but I my mistress’ thrall,
# Came there for cure and this by that I prove,
# Love’s fire heats water, water cools not love.
# THE END
# AL"
# r men discased, but I my mistress’ thrall,
# Came there for cure and this by that I prove,
# Love’s fire heats water, water cools not love.
# THE END
#
#
#
#
#
#
#
#
# Shene une heanth so condspole so
# 75/75 [==============================] - 25s 332ms/step - loss: 1.9582 - val_loss: 1.8590
# Epoch 25/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9512
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "his written embassage
# To witness duty, not to show my wit.
# Duty so great, which wit so poor as mine
# May make seem bare, in wanting words to show it"
# his written embassage
# To witness duty, not to show my wit.
# Duty so great, which wit so poor as mine
#
#
#
#
#
#
#
#
#
# Wht ong:shaulmis
# 75/75 [==============================] - 25s 328ms/step - loss: 1.9512 - val_loss: 1.8606
# Epoch 26/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9399
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "e own sweet argument, too excellent,
# For every vulgar paper to rehearse?
# O give thy self the thanks if aught in me,
# Worthy perusal stand against th"
# e own sweet argument, too excellent,
# For every vulgar paper to rehearse?
# O give thy self the thanks if aught in me,
#
#
#
#
#
#
#
#
#
# Ro toomernom reor taind cwidte’s
# 75/75 [==============================] - 25s 331ms/step - loss: 1.9399 - val_loss: 1.8410
# Epoch 27/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9302
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "f an antique song.
# But were some child of yours alive that time,
# You should live twice in it, and in my rhyme.
# Shall I compare thee to a summer’s d"
# f an antique song.
# But were some child of yours alive that time,
# You should live twice in it, and in my rhyme.
#
#
#
#
#
#
#
#
#
#
# Whe erat tu
# 75/75 [==============================] - 24s 325ms/step - loss: 1.9302 - val_loss: 1.8391
# Epoch 28/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9208
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "ave added feathers to the learned’s wing,
# And given grace a double majesty.
# Yet be most proud of that which I compile,
# Whose influence is thine, an"
# ave added feathers to the learned’s wing,
# And given grace a double majesty.
# Yet be most proud of that which I compile,
#
#
#
#
# And ese, ahat io they thas pays you dratrsworight,A
#
#
#
#
# Thiob whence
# 75/75 [==============================] - 24s 326ms/step - loss: 1.9208 - val_loss: 1.8432
# Epoch 29/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9127
# ----- Generating text after Epoch: 28
# ----- Generating with seed: " of your liberty,
# And patience tame to sufferance bide each check,
# Without accusing you of injury.
# Be where you list, your charter is so strong,
# T"
#  of your liberty,
# And patience tame to sufferance bide each check,
# Without accusing you of injury.
# Be where you list, your charter is so strong,
#
#
#
#
#
#
#
#
# Covithee as lymaine I l
# 75/75 [==============================] - 25s 334ms/step - loss: 1.9127 - val_loss: 1.8209
# Epoch 30/100
# 75/75 [==============================] - ETA: 0s - loss: 1.9006
# ----- Generating text after Epoch: 29
# ----- Generating with seed: " barrenly perish:
# Look whom she best endowed, she gave thee more;
# Which bounteous gift thou shouldst in bounty cherish:
# She carved thee for her sea"
#  barrenly perish:
# Look whom she best endowed, she gave thee more;
# Which bounteous gift thou shouldst in bounty cherish:
#
#
#
#
#
#
#
#
# Dom sumed (well I oneerd but with nfteme med,
# 75/75 [==============================] - 24s 326ms/step - loss: 1.9006 - val_loss: 1.8146
# Epoch 31/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8932
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "at ever sweet,
# Was used in giving gentle doom:
# And taught it thus anew to greet:
# ‘I hate’ she altered with an end,
# That followed it as gentle day,"
# at ever sweet,
# Was used in giving gentle doom:
# And taught it thus anew to greet:
# ‘I hate’ she altered with an end,
#
#
#
#
#
#
#
#
#
# To thene relinck,
# 75/75 [==============================] - 24s 326ms/step - loss: 1.8932 - val_loss: 1.8065
# Epoch 32/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8865
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "self disgrace, knowing thy will,
# I will acquaintance strangle and look strange:
# Be absent from thy walks and in my tongue,
# Thy sweet beloved name n"
# self disgrace, knowing thy will,
# I will acquaintance strangle and look strange:
# Be absent from thy walks and in my tongue,
#
#
#
#
#
#
#
#
#
# For that it noidic
# 75/75 [==============================] - 25s 329ms/step - loss: 1.8865 - val_loss: 1.7988
# Epoch 33/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8765
# ----- Generating text after Epoch: 32
# ----- Generating with seed: " leisure with my moan.
# Receiving nought by elements so slow,
# But heavy tears, badges of either’s woe.
# "
#  leisure with my moan.
# Receiving nought by elements so slow,
# But heavy tears, badges of either’s woe.
# The other two, slight air, and purging fire,
#
#
#
#
#
#
#
#
#
# The tead love, my gulds I thee has
# 75/75 [==============================] - 24s 322ms/step - loss: 1.8765 - val_loss: 1.8020
# Epoch 34/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8644
# ----- Generating text after Epoch: 33
# ----- Generating with seed: "en body’s work’s expired.
# For then my thoughts (from far where I abide)
# Intend a zealous pilgrimage to thee,
# And keep my drooping eyelids open wide"
# en body’s work’s expired.
# For then my thoughts (from far where I abide)
# Intend a zealous pilgrimage to thee,
#
#
#
#
#
#
#
#
#
#
# Whish lode sheipl) goth
# 75/75 [==============================] - 25s 329ms/step - loss: 1.8644 - val_loss: 1.7904
# Epoch 35/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8595
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "ndness shaken
# As I by yours, y’have passed a hell of time,
# And I a tyrant have no leisure taken
# To weigh how once I suffered in your crime.
# O that"
# ndness shaken
# As I by yours, y’have passed a hell of time,
# And I a tyrant have no leisure taken
# To weigh how once I suffered in your crime.
#
#
#
#
#
#
#
#
#
# Comi
# 75/75 [==============================] - 24s 324ms/step - loss: 1.8595 - val_loss: 1.7841
# Epoch 36/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8536
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "thing they see.
# For I have sworn thee fair: more perjured I,
# To swear against the truth so foul a be.
# Cupid laid by his brand and fell asleep,
# A m"
# thing they see.
# For I have sworn thee fair: more perjured I,
# To swear against the truth so foul a be.
# Cupid laid by his brand and fell asleep,
#
#
#
#
#
#
#
#
#
# Kndefring
# 75/75 [==============================] - 24s 324ms/step - loss: 1.8536 - val_loss: 1.7726
# Epoch 37/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8422
# ----- Generating text after Epoch: 36
# ----- Generating with seed: " play the mother’s part, kiss me, be kind.
# So will I pray that thou mayst have thy Will,
# If thou turn back and my loud crying still.
# Two loves I ha"
#  play the mother’s part, kiss me, be kind.
# So will I pray that thou mayst have thy Will,
# If thou turn back and my loud crying still.
#
#
#
#
#
#
#
# When in than histhourI live agained lecter
#
# 75/75 [==============================] - 25s 334ms/step - loss: 1.8422 - val_loss: 1.7708
# Epoch 38/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8363
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "so wary,
# As I not for my self, but for thee will,
# Bearing thy heart which I will keep so chary
# As tender nurse her babe from faring ill.
# Presume n"
# so wary,
# As I not for my self, but for thee will,
# Bearing thy heart which I will keep so chary
# As tender nurse her babe from faring ill.
#
#
#
#
#
#
#
#
#
# Ama
# 75/75 [==============================] - 25s 332ms/step - loss: 1.8363 - val_loss: 1.7644
# Epoch 39/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8301
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "of that right,
# My heart doth plead that thou in him dost lie,
# (A closet never pierced with crystal eyes)
# But the defendant doth that plea deny,
# An"
# of that right,
# My heart doth plead that thou in him dost lie,
# (A closet never pierced with crystal eyes)
# But the defendant doth that plea deny,
#
#
#
#
#
#
#
#
#
# And tor in
# 75/75 [==============================] - 25s 336ms/step - loss: 1.8301 - val_loss: 1.7584
# Epoch 40/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8207
# ----- Generating text after Epoch: 39
# ----- Generating with seed: " got my use,
# And under thee their poesy disperse.
# Thine eyes, that taught the dumb on high to sing,
# And heavy ignorance aloft to fly,
# Have added f"
#  got my use,
# And under thee their poesy disperse.
# Thine eyes, that taught the dumb on high to sing,
# And heavy ignorance aloft to fly,
#
#
#
#
#
#
#
#
#
# Then a dorofech on
# 75/75 [==============================] - 24s 325ms/step - loss: 1.8207 - val_loss: 1.7566
# Epoch 41/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8164
# ----- Generating text after Epoch: 40
# ----- Generating with seed: ",
# To dry the rain on my storm-beaten face,
# For no man well of such a salve can speak,
# That heals the wound, and cures not the disgrace:
# Nor can th"
# ,
# To dry the rain on my storm-beaten face,
# For no man well of such a salve can speak,
# That heals the wound, and cures not the disgrace:
#
#
#
#
#
#
#
#
#
# As detimy your follit ur
# 75/75 [==============================] - 25s 331ms/step - loss: 1.8164 - val_loss: 1.7538
# Epoch 42/100
# 75/75 [==============================] - ETA: 0s - loss: 1.8059
# ----- Generating text after Epoch: 41
# ----- Generating with seed: "r mourn for me when I am dead,
# Than you shall hear the surly sullen bell
# Give warning to the world that I am fled
# From this vile world with vilest "
# r mourn for me when I am dead,
# Than you shall hear the surly sullen bell
# Give warning to the world that I am fled
#
# Shat it hod twenclich il whrre mo thee to bug,.
#
#
#
#
#
#
#
#
# Nor hin mo are doth
# 75/75 [==============================] - 25s 331ms/step - loss: 1.8059 - val_loss: 1.7482
# Epoch 43/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7998
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "llayed,
# To-morrow sharpened in his former might.
# So love be thou, although to-day thou fill
# Thy hungry eyes, even till they wink with fulness,
# To-"
# llayed,
# To-morrow sharpened in his former might.
# So love be thou, although to-day thou fill
# Thy hungry eyes, even till they wink with fulness,
#
#
#
#
#
#
#
#
#
# When I san
# 75/75 [==============================] - 24s 324ms/step - loss: 1.7998 - val_loss: 1.7462
# Epoch 44/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7912
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "rom you have I been absent in the spring,
# When proud-pied April (dressed in all his trim)
# Hath put a spirit of youth in every thing:
# That heavy Sat"
# rom you have I been absent in the spring,
# When proud-pied April (dressed in all his trim)
# Hath put a spirit of youth in every thing:
#
#
#
#
#
#
#
#
# But whel gose so erw though but is fon
# 75/75 [==============================] - 25s 330ms/step - loss: 1.7912 - val_loss: 1.7433
# Epoch 45/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7869
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "w,
# Want nothing that the thought of hearts can mend:
# All tongues (the voice of souls) give thee that due,
# Uttering bare truth, even so as foes comm"
# w,
# Want nothing that the thought of hearts can mend:
# All tongues (the voice of souls) give thee that due,
#
# Than tree shall as adpoit so glow I !
#
#
#
#
#
#
#
#
# Lorker
# 75/75 [==============================] - 24s 325ms/step - loss: 1.7869 - val_loss: 1.7389
# Epoch 46/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7784
# ----- Generating text after Epoch: 45
# ----- Generating with seed: "oying sweetness,
# To bitter sauces did I frame my feeding;
# And sick of welfare found a kind of meetness,
# To be diseased ere that there was true need"
# oying sweetness,
# To bitter sauces did I frame my feeding;
# And sick of welfare found a kind of meetness,
#
#
#
#
#
#
#
#
#
#
# Wh
# 75/75 [==============================] - 25s 328ms/step - loss: 1.7784 - val_loss: 1.7371
# Epoch 47/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7731
# ----- Generating text after Epoch: 46
# ----- Generating with seed: "n appetite,
# Which but to-day by feeding is allayed,
# To-morrow sharpened in his former might.
# So love be thou, although to-day thou fill
# Thy hungry"
# n appetite,
# Which but to-day by feeding is allayed,
# To-morrow sharpened in his former might.
# So love be thou, although to-day thou fill
#
#
#
#
#
#
#
#
#
# I meare be thy vi
# 75/75 [==============================] - 25s 333ms/step - loss: 1.7731 - val_loss: 1.7273
# Epoch 48/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7675
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "From his low tract and look another way:
# So thou, thy self out-going in thy noon:
# Unlooked on diest unless thou get a son.
# Music to hear, why hear’"
# From his low tract and look another way:
# So thou, thy self out-going in thy noon:
# Unlooked on diest unless thou get a son.
#
#
#
#
#
#
#
#
# Your narow’t plaise mose sbll thap cunket
# 75/75 [==============================] - 25s 329ms/step - loss: 1.7675 - val_loss: 1.7257
# Epoch 49/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7640
# ----- Generating text after Epoch: 48
# ----- Generating with seed: " your sweet self resemble,
# Creating every bad a perfect best
# As fast as objects to his beams assemble:
# O ’tis the first, ’tis flattery in my seeing"
#  your sweet self resemble,
# Creating every bad a perfect best
# As fast as objects to his beams assemble:
#
#
#
#
#
#
#
#
#
# That for this withess, ard rook on tour ra
# 75/75 [==============================] - 25s 332ms/step - loss: 1.7640 - val_loss: 1.7261
# Epoch 50/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7569
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "s glass and she in thee
# Calls back the lovely April of her prime,
# So thou through windows of thine age shalt see,
# Despite of wrinkles this thy gold"
# s glass and she in thee
# Calls back the lovely April of her prime,
# So thou through windows of thine age shalt see,
#
#
#
#
#
#
#
#
#
# Or whry st me now th
# 75/75 [==============================] - 24s 324ms/step - loss: 1.7569 - val_loss: 1.7312
# Epoch 51/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7465
# ----- Generating text after Epoch: 50
# ----- Generating with seed: "That thou hast her it is not all my grief,
# And yet it may be said I loved her dearly,
# That she hath thee is of my wailing chief,
# A loss in love tha"
# That thou hast her it is not all my grief,
# And yet it may be said I loved her dearly,
# That she hath thee is of my wailing chief,
#
#
#
#
#
#
#
#
#
# To nequeauly in time ond y
# 75/75 [==============================] - 24s 324ms/step - loss: 1.7465 - val_loss: 1.7180
# Epoch 52/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7401
# ----- Generating text after Epoch: 51
# ----- Generating with seed: "rtuous lie,
# To do more for me than mine own desert,
# And hang more praise upon deceased I,
# Than niggard truth would willingly impart:
# O lest your t"
# rtuous lie,
# To do more for me than mine own desert,
# And hang more praise upon deceased I,
# Than niggard truth would willingly impart:
#
#
#
#
#
#
#
#
#
# Whi
# 75/75 [==============================] - 25s 329ms/step - loss: 1.7401 - val_loss: 1.7180
# Epoch 53/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7364
# ----- Generating text after Epoch: 52
# ----- Generating with seed: "
# But now is black beauty’s successive heir,
# And beauty slandered with a bastard shame,
# For since each hand hath put on nature’s power,
# Fairing the"
#
# But now is black beauty’s successive heir,
# And beauty slandered with a bastard shame,
# For since each hand hath put on nature’s power,
#
#
#
#
#
#
#
#
#
# To divened l
# 75/75 [==============================] - 24s 325ms/step - loss: 1.7364 - val_loss: 1.7163
# Epoch 54/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7309
# ----- Generating text after Epoch: 53
# ----- Generating with seed: "Or durst inhabit on a living brow:
# Before the golden tresses of the dead,
# The right of sepulchres, were shorn away,
# To live a second life on second"
# Or durst inhabit on a living brow:
# Before the golden tresses of the dead,
# The right of sepulchres, were shorn away,
#
#
#
#
#
#
#
#
#
#
# Thencin
# 75/75 [==============================] - 25s 334ms/step - loss: 1.7309 - val_loss: 1.7154
# Epoch 55/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7221
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "d when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
# Ay me, but yet thou mightst my seat forbear,
# And chide thy bea"
# d when a woman woos, what woman’s son,
# Will sourly leave her till he have prevailed?
# Ay me, but yet thou mightst my seat forbear,
#
#
#
#
#
#
#
#
#
# ’Tt thou
# 75/75 [==============================] - 24s 325ms/step - loss: 1.7221 - val_loss: 1.7076
# Epoch 56/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7147
# ----- Generating text after Epoch: 55
# ----- Generating with seed: "Let those who are in favour with their stars,
# Of public honour and proud titles boast,
# Whilst I whom fortune of such triumph bars
# Unlooked for joy "
# Let those who are in favour with their stars,
# Of public honour and proud titles boast,
# Whilst I whom fortune of such triumph bars
#
#
#
#
#
#
#
#
#
# Thesera asseves courwad
# 75/75 [==============================] - 24s 325ms/step - loss: 1.7147 - val_loss: 1.7049
# Epoch 57/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7117
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "
# In gentle numbers time so idly spent,
# Sing to the ear that doth thy lays esteem,
# And gives thy pen both skill and argument.
# Rise resty Muse, my lo"
#
# In gentle numbers time so idly spent,
# Sing to the ear that doth thy lays esteem,
# And gives thy pen both skill and argument.
#
#
#
#
#
#
#
#
#
# Frathy us the brausies,
# 75/75 [==============================] - 25s 330ms/step - loss: 1.7117 - val_loss: 1.7039
# Epoch 58/100
# 75/75 [==============================] - ETA: 0s - loss: 1.7026
# ----- Generating text after Epoch: 57
# ----- Generating with seed: "f am mortgaged to thy will,
# My self I’ll forfeit, so that other mine,
# Thou wilt restore to be my comfort still:
# But thou wilt not, nor he will not "
# f am mortgaged to thy will,
# My self I’ll forfeit, so that other mine,
# Thou wilt restore to be my comfort still:
#
#
#
#
#
#
#
#
#
# Thy iegser’s bair p
# 75/75 [==============================] - 24s 325ms/step - loss: 1.7026 - val_loss: 1.7025
# Epoch 59/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6974
# ----- Generating text after Epoch: 58
# ----- Generating with seed: "ay,
# Which husbandry in honour might uphold,
# Against the stormy gusts of winter’s day
# And barren rage of death’s eternal cold?
# O none but unthrifts"
# ay,
# Which husbandry in honour might uphold,
# Against the stormy gusts of winter’s day
# And barren rage of death’s eternal cold?
#
#
#
#
#
#
#
#
# And rat on ment, ho even thoughs paoth
# 75/75 [==============================] - 24s 325ms/step - loss: 1.6974 - val_loss: 1.7009
# Epoch 60/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6926
# ----- Generating text after Epoch: 59
# ----- Generating with seed: " keep her treasure!
# Her audit (though delayed) answered must be,
# And her quietus is to render thee.
# In the old age black was not counted fair,
# Or "
#  keep her treasure!
# Her audit (though delayed) answered must be,
# And her quietus is to render thee.
# In the old age black was not counted fair,
#
#
#
#
#
#
#
#
#
# For th
# 75/75 [==============================] - 25s 331ms/step - loss: 1.6926 - val_loss: 1.7032
# Epoch 61/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6910
# ----- Generating text after Epoch: 60
# ----- Generating with seed: "brain
# Full charactered with lasting memory,
# Which shall above that idle rank remain
# Beyond all date even to eternity.
# Or at the least, so long as "
# brain
# Full charactered with lasting memory,
# Which shall above that idle rank remain
# Beyond all date even to eternity.
#
#
#
#
#
#
#
#
#
# My lose my thome mays ever waspest
# 75/75 [==============================] - 24s 325ms/step - loss: 1.6910 - val_loss: 1.6991
# Epoch 62/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6823
# ----- Generating text after Epoch: 61
# ----- Generating with seed: "sty days;
# To say, within thine own deep sunken eyes,
# Were an all-eating shame, and thriftless praise.
# How much more praise deserv’d thy beauty’s us"
# sty days;
# To say, within thine own deep sunken eyes,
# Were an all-eating shame, and thriftless praise.
#
#
#
#
#
#
#
#
#
#
# The sth
# 75/75 [==============================] - 25s 328ms/step - loss: 1.6823 - val_loss: 1.7005
# Epoch 63/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6748
# ----- Generating text after Epoch: 62
# ----- Generating with seed: "
# Since what he owes thee, thou thy self dost pay.
# O how I faint when I of you do write,
# Knowing a better spirit doth use your name,
# And in the pra"
#
# Since what he owes thee, thou thy self dost pay.
# O how I faint when I of you do write,
# Knowing a better spirit doth use your name,
#
#
#
#
#
#
#
#
#
# Deitirebe
# 75/75 [==============================] - 24s 326ms/step - loss: 1.6748 - val_loss: 1.6957
# Epoch 64/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6705
# ----- Generating text after Epoch: 63
# ----- Generating with seed: "ing store with loss, and loss with store.
# When I have seen such interchange of State,
# Or state it self confounded, to decay,
# Ruin hath taught me th"
# ing store with loss, and loss with store.
# When I have seen such interchange of State,
# Or state it self confounded, to decay,
#
#
#
#
#
#
#
#
# Hen I crang night did me burmem, ore;
#
# T
# 75/75 [==============================] - 24s 327ms/step - loss: 1.6705 - val_loss: 1.6979
# Epoch 65/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6634
# ----- Generating text after Epoch: 64
# ----- Generating with seed: "for my stain,
# Never believe though in my nature reigned,
# All frailties that besiege all kinds of blood,
# That it could so preposterously be stained,"
# for my stain,
# Never believe though in my nature reigned,
# All frailties that besiege all kinds of blood,
#
#
# And rienct of merers all, act I hack p
#
#
#
#
#
#
#
#
# So
# 75/75 [==============================] - 25s 329ms/step - loss: 1.6634 - val_loss: 1.6924
# Epoch 66/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6594
# ----- Generating text after Epoch: 65
# ----- Generating with seed: "tion did decree,
# That in thy face sweet love should ever dwell,
# Whate’er thy thoughts, or thy heart’s workings be,
# Thy looks should nothing thence,"
# tion did decree,
# That in thy face sweet love should ever dwell,
# Whate’er thy thoughts, or thy heart’s workings be,
#
#
#
#
#
#
#
# The gruan ofthersing hare muthmert to e
#
#
# As say so love, shald though she and
# 75/75 [==============================] - 25s 327ms/step - loss: 1.6594 - val_loss: 1.7012
# Epoch 67/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6514
# ----- Generating text after Epoch: 66
# ----- Generating with seed: "lf to win!
# What wretched errors hath my heart committed,
# Whilst it hath thought it self so blessed never!
# How have mine eyes out of their spheres b"
# lf to win!
# What wretched errors hath my heart committed,
# Whilst it hath thought it self so blessed never!
#
#
#
#
#
#
#
#
#
#
# When b
# 75/75 [==============================] - 25s 329ms/step - loss: 1.6514 - val_loss: 1.7010
# Epoch 68/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6464
# ----- Generating text after Epoch: 67
# ----- Generating with seed: "eauty’s veil doth cover every blot,
# And all things turns to fair, that eyes can see!
# Take heed (dear heart) of this large privilege,
# The hardest kn"
# eauty’s veil doth cover every blot,
# And all things turns to fair, that eyes can see!
# Take heed (dear heart) of this large privilege,
#
#
#
#
#
#
#
#
#
# To grais I formbr an
# 75/75 [==============================] - 24s 325ms/step - loss: 1.6464 - val_loss: 1.6984
# Epoch 69/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6407
# ----- Generating text after Epoch: 68
# ----- Generating with seed: "why of two oaths’ breach do I accuse thee,
# When I break twenty? I am perjured most,
# For all my vows are oaths but to misuse thee:
# And all my honest"
# why of two oaths’ breach do I accuse thee,
# When I break twenty? I am perjured most,
# For all my vows are oaths but to misuse thee:
#
#
#
# Sacksprained to will priais have blacked formbk
#
#
#
#
# In secl hace batter ty stoll lelder dears
#
# In th
# 75/75 [==============================] - 24s 324ms/step - loss: 1.6407 - val_loss: 1.7021
# Epoch 70/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6383
# ----- Generating text after Epoch: 69
# ----- Generating with seed: "e’s sweet face survey,
# If time have any wrinkle graven there,
# If any, be a satire to decay,
# And make time’s spoils despised everywhere.
# Give my lo"
# e’s sweet face survey,
# If time have any wrinkle graven there,
# If any, be a satire to decay,
# And make time’s spoils despised everywhere.
#
#
#
#
#
#
#
#
#
# But muntane plur of fortle policest poscise
# 75/75 [==============================] - 25s 330ms/step - loss: 1.6383 - val_loss: 1.7030
# Epoch 71/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6340
# ----- Generating text after Epoch: 70
# ----- Generating with seed: "th in you doth grow.
# This silence for my sin you did impute,
# Which shall be most my glory being dumb,
# For I impair not beauty being mute,
# When oth"
# th in you doth grow.
# This silence for my sin you did impute,
# Which shall be most my glory being dumb,
# For I impair not beauty being mute,
#
#
#
#
#
#
#
#
#
# Fart
# 75/75 [==============================] - 24s 325ms/step - loss: 1.6340 - val_loss: 1.6911
# Epoch 72/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6233
# ----- Generating text after Epoch: 71
# ----- Generating with seed: "O lest your true love may seem false in this,
# That you for love speak well of me untrue,
# My name be buried where my body is,
# And live no more to sh"
# O lest your true love may seem false in this,
# That you for love speak well of me untrue,
# My name be buried where my body is,
#
#
#
#
#
#
#
#
#
# And pooow not se go
# 75/75 [==============================] - 25s 329ms/step - loss: 1.6233 - val_loss: 1.6949
# Epoch 73/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6195
# ----- Generating text after Epoch: 72
# ----- Generating with seed: "owing a bath and healthful remedy,
# For men discased, but I my mistress’ thrall,
# Came there for cure and this by that I prove,
# Love’s fire heats wat"
# owing a bath and healthful remedy,
# For men discased, but I my mistress’ thrall,
# Came there for cure and this by that I prove,
#
#
#
#
#
#
#
#
#
# Thece sillen braunt, in bll
# 75/75 [==============================] - 24s 325ms/step - loss: 1.6195 - val_loss: 1.6926
# Epoch 74/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6235
# ----- Generating text after Epoch: 73
# ----- Generating with seed: "have scanted all,
# Wherein I should your great deserts repay,
# Forgot upon your dearest love to call,
# Whereto all bonds do tie me day by day,
# That I"
# have scanted all,
# Wherein I should your great deserts repay,
# Forgot upon your dearest love to call,
# Whereto all bonds do tie me day by day,
#
#
#
#
#
#
#
#
#
# When dost ty grame, that
# 75/75 [==============================] - 24s 326ms/step - loss: 1.6235 - val_loss: 1.6847
# Epoch 75/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6119
# ----- Generating text after Epoch: 74
# ----- Generating with seed: "contented least,
# Yet in these thoughts my self almost despising,
# Haply I think on thee, and then my state,
# (Like to the lark at break of day arisin"
# contented least,
# Yet in these thoughts my self almost despising,
# Haply I think on thee, and then my state,
#
#
#
#
#
#
#
#
#
# Iy blosed muspess Indou leave a
# 75/75 [==============================] - 25s 329ms/step - loss: 1.6119 - val_loss: 1.6970
# Epoch 76/100
# 75/75 [==============================] - ETA: 0s - loss: 1.6093
# ----- Generating text after Epoch: 75
# ----- Generating with seed: "utbraves his dignity:
# For sweetest things turn sourest by their deeds,
# Lilies that fester, smell far worse than weeds.
# How sweet and lovely dost th"
# utbraves his dignity:
# For sweetest things turn sourest by their deeds,
# Lilies that fester, smell far worse than weeds.
#
#
#
#
#
#
#
#
# Shout I op hands say love revent
# 75/75 [==============================] - 24s 324ms/step - loss: 1.6093 - val_loss: 1.6930
# Epoch 77/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5979
# ----- Generating text after Epoch: 76
# ----- Generating with seed: "etty looks have been mine enemies,
# And therefore from my face she turns my foes,
# That they elsewhere might dart their injuries:
# Yet do not so, but "
# etty looks have been mine enemies,
# And therefore from my face she turns my foes,
# That they elsewhere might dart their injuries:
#
#
#
# Seefes sumber shocks, and to the would in hear
#
#
#
#
#
#
# That what in
# 75/75 [==============================] - 25s 329ms/step - loss: 1.5979 - val_loss: 1.6910
# Epoch 78/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5891
# ----- Generating text after Epoch: 77
# ----- Generating with seed: "ery one, hath every one, one shade,
# And you but one, can every shadow lend:
# Describe Adonis and the counterfeit,
# Is poorly imitated after you,
# On "
# ery one, hath every one, one shade,
# And you but one, can every shadow lend:
# Describe Adonis and the counterfeit,
# Is poorly imitated after you,
#
#
#
#
#
#
#
#
# With leaves far one wo ng c
# 75/75 [==============================] - 24s 324ms/step - loss: 1.5891 - val_loss: 1.6962
# Epoch 79/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5882
# ----- Generating text after Epoch: 78
# ----- Generating with seed: "u must live drawn by your own sweet skill.
# Who will believe my verse in time to come
# If it were filled with your most high deserts?
# Though yet heav"
# u must live drawn by your own sweet skill.
# Who will believe my verse in time to come
# If it were filled with your most high deserts?
#
#
#
#
#
#
#
#
# Nomedo concanet wish gones) in sunder endoo
# 75/75 [==============================] - 25s 331ms/step - loss: 1.5882 - val_loss: 1.6943
# Epoch 80/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5824
# ----- Generating text after Epoch: 79
# ----- Generating with seed: "d quite,
# And all the rest forgot for which he toiled:
# Then happy I that love and am beloved
# Where I may not remove nor be removed.
# Lord of my love"
# d quite,
# And all the rest forgot for which he toiled:
# Then happy I that love and am beloved
# Where I may not remove nor be removed.
#
#
#
#
#
#
#
#
#
# Whea should lemmer blo
# 75/75 [==============================] - 25s 328ms/step - loss: 1.5824 - val_loss: 1.6911
# Epoch 81/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5756
# ----- Generating text after Epoch: 80
# ----- Generating with seed: "looks his sacred majesty,
# And having climbed the steep-up heavenly hill,
# Resembling strong youth in his middle age,
# Yet mortal looks adore his beau"
# looks his sacred majesty,
# And having climbed the steep-up heavenly hill,
# Resembling strong youth in his middle age,
#
#
#
#
#
#
#
#
# Mure hanbeding you, the fiarly us olllyely?h
# And my lose bes ioler that
# 75/75 [==============================] - 24s 324ms/step - loss: 1.5756 - val_loss: 1.6951
# Epoch 82/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5699
# ----- Generating text after Epoch: 81
# ----- Generating with seed: "oet’s debt:
# And therefore have I slept in your report,
# That you your self being extant well might show,
# How far a modern quill doth come too short,"
# oet’s debt:
# And therefore have I slept in your report,
# That you your self being extant well might show,
#
#
#
#
#
#
#
#
#
# Thich the find in sourt
# 75/75 [==============================] - 25s 328ms/step - loss: 1.5699 - val_loss: 1.6921
# Epoch 83/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5660
# ----- Generating text after Epoch: 82
# ----- Generating with seed: "ct,
# For slander’s mark was ever yet the fair,
# The ornament of beauty is suspect,
# A crow that flies in heaven’s sweetest air.
# So thou be good, slan"
# ct,
# For slander’s mark was ever yet the fair,
# The ornament of beauty is suspect,
# A crow that flies in heaven’s sweetest air.
#
#
#
#
#
#
#
#
#
# If I
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5660 - val_loss: 1.6950
# Epoch 84/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5604
# ----- Generating text after Epoch: 83
# ----- Generating with seed: "ll,
# Lest I (too much profane) should do it wronk:
# And haply of our old acquaintance tell.
# For thee, against my self I’ll vow debate,
# For I must ne"
# ll,
# Lest I (too much profane) should do it wronk:
# And haply of our old acquaintance tell.
# For thee, against my self I’ll vow debate,
#
#
#
#
#
#
#
#
#
# Thou make so goven you to kne.
# 75/75 [==============================] - 24s 325ms/step - loss: 1.5604 - val_loss: 1.6989
# Epoch 85/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5591
# ----- Generating text after Epoch: 84
# ----- Generating with seed: "essary needs must be,
# To that sweet thief which sourly robs from me.
# Let me confess that we two must be twain,
# Although our undivided loves are one"
# essary needs must be,
# To that sweet thief which sourly robs from me.
# Let me confess that we two must be twain,
#
#
#
#
#
#
#
#
#
#
# Tooming anfelf tnot sweet i
# 75/75 [==============================] - 25s 328ms/step - loss: 1.5591 - val_loss: 1.7005
# Epoch 86/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5529
# ----- Generating text after Epoch: 85
# ----- Generating with seed: "st thou too, and therein dignified:
# Make answer Muse, wilt thou not haply say,
# ’Truth needs no colour with his colour fixed,
# Beauty no pencil, beau"
# st thou too, and therein dignified:
# Make answer Muse, wilt thou not haply say,
# ’Truth needs no colour with his colour fixed,
#
#
#
#
#
#
# And wakes of hene patiends of dot.
#
#
#
# Where bre manesue in toe, that
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5529 - val_loss: 1.6998
# Epoch 87/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5431
# ----- Generating text after Epoch: 86
# ----- Generating with seed: "! thou art too dear for my possessing,
# And like enough thou know’st thy estimate,
# The charter of thy worth gives thee releasing:
# My bonds in thee a"
# ! thou art too dear for my possessing,
# And like enough thou know’st thy estimate,
# The charter of thy worth gives thee releasing:
#
#
#
#
#
#
#
#
#
# When thou toy p
# 75/75 [==============================] - 25s 329ms/step - loss: 1.5431 - val_loss: 1.6974
# Epoch 88/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5401
# ----- Generating text after Epoch: 87
# ----- Generating with seed: "p vermilion in the rose,
# They were but sweet, but figures of delight:
# Drawn after you, you pattern of all those.
# Yet seemed it winter still, and yo"
# p vermilion in the rose,
# They were but sweet, but figures of delight:
# Drawn after you, you pattern of all those.
#
#
#
#
#
#
#
#
#
# Whe
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5401 - val_loss: 1.7081
# Epoch 89/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5362
# ----- Generating text after Epoch: 88
# ----- Generating with seed: "hen might I not say so
# To give full growth to that which still doth grow.
# Let me not to the marriage of true minds
# Admit impediments, love is not l"
# hen might I not say so
# To give full growth to that which still doth grow.
# Let me not to the marriage of true minds
#
#
#
#
#
#
#
#
#
#
# S
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5362 - val_loss: 1.7040
# Epoch 90/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5317
# ----- Generating text after Epoch: 89
# ----- Generating with seed: "e,
# Mine own true love that doth my rest defeat,
# To play the watchman ever for thy sake.
# For thee watch I, whilst thou dost wake elsewhere,
# From me"
# e,
# Mine own true love that doth my rest defeat,
# To play the watchman ever for thy sake.
# For thee watch I, whilst thou dost wake elsewhere,
#
#
#
#
#
#
#
#
#
# And ondecrees
# 75/75 [==============================] - 25s 328ms/step - loss: 1.5317 - val_loss: 1.7018
# Epoch 91/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5284
# ----- Generating text after Epoch: 90
# ----- Generating with seed: "eauty of thy mind,
# And that in guess they measure by thy deeds,
# Then churls their thoughts (although their eyes were kind)
# To thy fair flower add t"
# eauty of thy mind,
# And that in guess they measure by thy deeds,
# Then churls their thoughts (although their eyes were kind)
#
#
#
#
#
#
#
#
#
# Whose wiet t
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5284 - val_loss: 1.7058
# Epoch 92/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5215
# ----- Generating text after Epoch: 91
# ----- Generating with seed: " my grief,
# And yet it may be said I loved her dearly,
# That she hath thee is of my wailing chief,
# A loss in love that touches me more nearly.
# Lovin"
#  my grief,
# And yet it may be said I loved her dearly,
# That she hath thee is of my wailing chief,
# A loss in love that touches me more nearly.
#
#
#
#
#
#
#
#
#
# And f
# 75/75 [==============================] - 25s 329ms/step - loss: 1.5215 - val_loss: 1.7099
# Epoch 93/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5171
# ----- Generating text after Epoch: 92
# ----- Generating with seed: "ow hard true sorrow hits,
# And soon to you, as you to me then tendered
# The humble salve, which wounded bosoms fits!
# But that your trespass now becom"
# ow hard true sorrow hits,
# And soon to you, as you to me then tendered
# The humble salve, which wounded bosoms fits!
#
#
#
#
#
#
#
#
#
# Seek sakety my dumper’s every
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5171 - val_loss: 1.7068
# Epoch 94/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5141
# ----- Generating text after Epoch: 93
# ----- Generating with seed: "ed, where all thy beauty lies,
# Where all the treasure of thy lusty days;
# To say, within thine own deep sunken eyes,
# Were an all-eating shame, and t"
# ed, where all thy beauty lies,
# Where all the treasure of thy lusty days;
# To say, within thine own deep sunken eyes,
#
#
#
#
#
#
#
#
#
#
# Nere
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5141 - val_loss: 1.7166
# Epoch 95/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5055
# ----- Generating text after Epoch: 94
# ----- Generating with seed: "part was consecrate to thee,
# The earth can have but earth, which is his due,
# My spirit is thine the better part of me,
# So then thou hast but lost t"
# part was consecrate to thee,
# The earth can have but earth, which is his due,
# My spirit is thine the better part of me,
#
#
#
#
#
#
#
#
#
# So look I do the traigious
# 75/75 [==============================] - 25s 328ms/step - loss: 1.5055 - val_loss: 1.7174
# Epoch 96/100
# 75/75 [==============================] - ETA: 0s - loss: 1.5015
# ----- Generating text after Epoch: 95
# ----- Generating with seed: "oks have been mine enemies,
# And therefore from my face she turns my foes,
# That they elsewhere might dart their injuries:
# Yet do not so, but since I"
# oks have been mine enemies,
# And therefore from my face she turns my foes,
# That they elsewhere might dart their injuries:
#
#
#
#
#
#
#
# Yet abestyour self, to degais theesides,
#
#
# He
# 75/75 [==============================] - 24s 323ms/step - loss: 1.5015 - val_loss: 1.7178
# Epoch 97/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4971
# ----- Generating text after Epoch: 96
# ----- Generating with seed: "and much enrich thy book.
# So oft have I invoked thee for my muse,
# And found such fair assistance in my verse,
# As every alien pen hath got my use,
# "
# and much enrich thy book.
# So oft have I invoked thee for my muse,
# And found such fair assistance in my verse,
# As every alien pen hath got my use,
#
#
#
#
#
#
#
#
#
# Pily
# 75/75 [==============================] - 24s 324ms/step - loss: 1.4971 - val_loss: 1.7095
# Epoch 98/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4939
# ----- Generating text after Epoch: 97
# ----- Generating with seed: "
# Whilst I thy babe chase thee afar behind,
# But if thou catch thy hope turn back to me:
# And play the mother’s part, kiss me, be kind.
# So will I pray"
#
# Whilst I thy babe chase thee afar behind,
# But if thou catch thy hope turn back to me:
# And play the mother’s part, kiss me, be kind.
#
#
#
#
#
#
#
#
#
# And ties-
# 75/75 [==============================] - 25s 328ms/step - loss: 1.4939 - val_loss: 1.7130
# Epoch 99/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4850
# ----- Generating text after Epoch: 98
# ----- Generating with seed: " mine own worth do define,
# As I all other in all worths surmount.
# But when my glass shows me my self indeed
# beated and chopt with tanned antiquity,"
#  mine own worth do define,
# As I all other in all worths surmount.
# But when my glass shows me my self indeed
#
#
#
#
#
#
#
#
#
#
# Shell divionrwit, b
# 75/75 [==============================] - 24s 323ms/step - loss: 1.4850 - val_loss: 1.7203
# Epoch 100/100
# 75/75 [==============================] - ETA: 0s - loss: 1.4844
# ----- Generating text after Epoch: 99
# ----- Generating with seed: "epy night,
# And all those beauties whereof now he’s king
# Are vanishing, or vanished out of sight,
# Stealing away the treasure of his spring:
# For suc"
# epy night,
# And all those beauties whereof now he’s king
# Are vanishing, or vanished out of sight,
# Stealing away the treasure of his spring:
#
#
#
#
#
#
#
#
#
# When in t
# 75/75 [==============================] - 25s 330ms/step - loss: 1.4844 - val_loss: 1.7177

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs

# %% [markdown]
# # Resources and Stretch Goals

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
